# %% [markdown]
# ###Fuente de la data
#
# Los micro-datos gestionados en este notebook son tomados de www.datos.gov.co y corresponden a datos cuya fuente primaria es el Instituto Nacional de Medicina Legal y Ciencias Forenses

# %%
import pandas as pd

# %% [markdown]
# ###Archivo 2kpj-cktv.csv
#
# Contiene información sobre las lesiones fatales de causa externa ocurridas en el territorio nacional Colombiano en el periodo de tiempo comprendido entre el 01 de enero de 2023 al 31 de julio e 2024, de los cuales tiene conocimiento y son registrados por Instituto Nacional de Medicina Legal y Ciencias Forenses.

# %%
df = pd.read_csv("https://www.datos.gov.co/resource/2kpj-cktv.csv?$limit=500000")
df.head(2)
# Out:
#    id  a_o_del_hecho sexo_de_la_victima grupo_de_edad_de_la_victima  \
# 0   1           2023             Hombre                   (15 a 17)
# 1   2           2023             Hombre                   (18 a 19)
#
#   mes_del_hecho dia_del_hecho departamento_del_hecho_dane  \
# 0         enero       domingo                Bogotá, D.C.
# 1         enero       domingo                Bogotá, D.C.
#
#   municipio_del_hecho_dane    lesion_fatal_de_causa_externa  \
# 0             Bogotá, D.C.  Violenta - Presuntos Homicidios
# 1             Bogotá, D.C.  Violenta - Presuntos Homicidios
#
#                                               estado
# 0  Datos preliminares sujetos a cambios por actua...
# 1  Datos preliminares sujetos a cambios por actua...

# %% [markdown]
# ###Archivo byjr-sbsy.csv
#
# Contiene información sobre las lesiones fatales de causa externa ocurridas en el territorio nacional Colombiano en el periodo de tiempo comprendido entre el 01 de enero de 2020 y 31 de diciembre de 2022, de los cuales tiene conocimiento y son registrados por el Instituto Nacional de Medicina Legal y Ciencias Forenses

# %%
df1 = pd.read_csv("https://www.datos.gov.co/resource/byjr-sbsy.csv?$limit=500000")
df1.head(2)
# Out:
#    id  a_o_del_hecho sexo_de_la_victima grupo_de_edad_de_la_victima  \
# 0   1           2021             Hombre                   (50 a 54)
# 1   2           2021             Hombre                   (18 a 19)
#
#   mes_del_hecho dia_del_hecho departamento_del_hecho_dane  \
# 0         Enero       Viernes                Bogotá, D.C.
# 1         Enero       Viernes                Bogotá, D.C.
#
#   municipio_del_hecho_dane    lesion_fatal_de_causa_externa             estado
# 0             Bogotá, D.C.  Violenta - Presuntos Homicidios  Datos definitivos
# 1             Bogotá, D.C.  Violenta - Presuntos Homicidios  Datos definitivos

# %% [markdown]
# ###Archivo vtub-3de2.csv
#
# Contiene información sobre los homicidios ocurridos en el territorio nacional Colombiano en el periodo de tiempo comprendido entre los años 2016 y 2019, de los cuales tiene conocimiento y son registrados por el Instituto Nacional de Medicina Legal y Ciencias Forenses.

# %%
df2 = pd.read_csv("https://www.datos.gov.co/resource/vtub-3de2.csv?$limit=500000")
df2.head(2)
# Out:
#    id  a_o_del_hecho sexo_de_la_victima grupo_de_edad_de_la_victima  \
# 0   1           2016             Hombre                   (25 a 29)
# 1   2           2016             Hombre                   (20 a 24)
#
#   mes_del_hecho dia_del_hecho departamento_del_hecho_dane  \
# 0         Enero        Jueves                        Meta
# 1         Enero     Miércoles                        Meta
#
#   municipio_del_hecho_dane lesion_fatal_de_causa_externa             estado
# 0                  Acacías         Violenta - Homicidios  Datos definitivos
# 1                  Acacías         Violenta - Homicidios  Datos definitivos

# %% [markdown]
# ###Archivo f75u-mirk.csv
#
# Contiene información sobre los suicidios ocurridos en el territorio nacional Colombiano en el periodo de tiempo comprendido entre los años 2016 y 2019, de los cuales tiene conocimiento y son registrados por el Instituto Nacional de Medicina Legal y Ciencias Forenses.

# %%
df3 = pd.read_csv("https://www.datos.gov.co/resource/f75u-mirk.csv?$limit=500000")
df3.head(2)
# Out:
#    id  a_o_del_hecho sexo_de_la_victima grupo_de_edad_de_la_victima  \
# 0   1           2016             Hombre                   (20 a 24)
# 1   2           2016             Hombre                   (50 a 54)
#
#   mes_del_hecho dia_del_hecho departamento_del_hecho_dane  \
# 0         Enero        Sábado                   Antioquia
# 1         Enero        Sábado                     Quindío
#
#   municipio_del_hecho_dane lesion_fatal_de_causa_externa             estado
# 0                 Apartadó          Violenta - Suicidios  Datos definitivos
# 1                  Armenia          Violenta - Suicidios  Datos definitivos

# %% [markdown]
# ###Archivo irg9-q5fx.csv
#
# Contiene información sobre las muertes accidentales ocurridas en el territorio nacional Colombiano en el periodo de tiempo comprendido entre los años 2016 y 2019, de los cuales tiene conocimiento y son registrados por el Instituto Nacional de Medicina Legal y Ciencias Forenses.

# %%
df4 = pd.read_csv("https://www.datos.gov.co/resource/irg9-q5fx.csv?$limit=500000")
df4.head(2)
# Out:
#    id  a_o_del_hecho sexo_de_la_victima grupo_de_edad_de_la_victima  \
# 0   1           2017             Hombre                   (40 a 44)
# 1   2           2017             Hombre                   (50 a 54)
#
#   mes_del_hecho dia_del_hecho departamento_del_hecho_dane  \
# 0       febrero        martes                        Meta
# 1       febrero        martes                        Meta
#
#   municipio_del_hecho_dane    lesion_fatal_de_causa_externa             estado
# 0     San Carlos de Guaroa  Violenta - Muertes accidentales  Datos definitivos
# 1                  Granada  Violenta - Muertes accidentales  Datos definitivos

# %% [markdown]
# ###Archivo s65h-7665.csv
#
# Contiene información sobre las muertes por accidentes de transporte ocurridas en el territorio nacional Colombiano en el periodo de tiempo comprendido entre los años 2016 y 2019, de los cuales tiene conocimiento y son registrados por el Instituto Nacional de Medicina Legal y Ciencias Forenses.

# %%
df5 = pd.read_csv("https://www.datos.gov.co/resource/s65h-7665.csv?$limit=500000")
df5.head(2)
# Out:
#    id  a_o_del_hecho sexo_de_la_victima grupo_de_edad_de_la_victima  \
# 0   1           2016             Hombre                   (25 a 29)
# 1   2           2016             Hombre                   (35 a 39)
#
#   mes_del_hecho dia_del_hecho departamento_del_hecho_dane  \
# 0         Enero        Sábado                        Meta
# 1         Enero       Domingo                        Meta
#
#   municipio_del_hecho_dane                   lesion_fatal_de_causa_externa  \
# 0     San Carlos de Guaroa  Violenta - Muertes en accidentes de transporte
# 1                  Acacías  Violenta - Muertes en accidentes de transporte
#
#               estado
# 0  Datos definitivos
# 1  Datos definitivos

# %% [markdown]
# ##Revisión y limpieza para integrarlo a la base de datos
#
# ### - Unir en forma vertical los 6 dataset en uno solo

# %%
# Lista de los DataFrames a unir
dataframes = [(df, 'df'), (df1, 'df1'), (df2, 'df2'), (df3, 'df3'), (df4, 'df4'), (df5, 'df5')]

# %%
# Verificar que tienen los mismos nombres de columnas

# Función que compara los nombres de las columnas de dos df
def compare_columns(df1, df2):
    if df1.columns.equals(df2.columns):
        return True
    else:
        return False

# Seleccionar el primer DataFrame como referencia
df_reference = dataframes[0][0]

# Comparar cada DataFrame con el de referencia
for d, name in dataframes[1:]:
    if compare_columns(df_reference, d):
      print(f"Los DataFrames {dataframes[0][1]} y {name} tienen las mismas columnas.")
# Out:
# Los DataFrames df y df1 tienen las mismas columnas.
# Los DataFrames df y df2 tienen las mismas columnas.
# Los DataFrames df y df3 tienen las mismas columnas.
# Los DataFrames df y df4 tienen las mismas columnas.
# Los DataFrames df y df5 tienen las mismas columnas.

# %%
# Comparar los tipos de datos de las columnas correspondientes
for col in df_reference.columns:
    for d, name in dataframes[1:]:
        if d[col].dtype != df_reference[col].dtype:
            print(f"La columna '{col}' tiene diferentes tipos de datos en los DataFrames.")

# %%
# Unir los DataFrames verticalmente
dfs = [d for d, _ in dataframes]
fatal_injuries_ML = pd.concat(dfs, axis = 0, ignore_index=True)
fatal_injuries_ML.head()
# Out:
#    id  a_o_del_hecho sexo_de_la_victima grupo_de_edad_de_la_victima  \
# 0   1           2023             Hombre                   (15 a 17)
# 1   2           2023             Hombre                   (18 a 19)
# 2   3           2023             Hombre                   (20 a 24)
# 3   4           2023             Hombre                   (30 a 34)
# 4   5           2023             Hombre                   (20 a 24)
#
#   mes_del_hecho dia_del_hecho departamento_del_hecho_dane  \
# 0         enero       domingo                Bogotá, D.C.
# 1         enero       domingo                Bogotá, D.C.
# 2         enero       domingo                Bogotá, D.C.
# 3         enero       domingo                Bogotá, D.C.
# 4         enero       domingo                Bogotá, D.C.
#
#   municipio_del_hecho_dane    lesion_fatal_de_causa_externa  \
# 0             Bogotá, D.C.  Violenta - Presuntos Homicidios
# 1             Bogotá, D.C.  Violenta - Presuntos Homicidios
# 2             Bogotá, D.C.  Violenta - Presuntos Homicidios
# 3             Bogotá, D.C.  Violenta - Presuntos Homicidios
# 4             Bogotá, D.C.  Violenta - Presuntos Homicidios
#
#                                               estado
# 0  Datos preliminares sujetos a cambios por actua...
# 1  Datos preliminares sujetos a cambios por actua...
# 2  Datos preliminares sujetos a cambios por actua...
# 3  Datos preliminares sujetos a cambios por actua...
# 4  Datos preliminares sujetos a cambios por actua...

# %%
len(df) + len(df1) + len(df2) + len(df3) + len(df4) + len(df5) == len(fatal_injuries_ML)
# Out:
# True

# %% [markdown]
# ### - Resumen de la estructura del dataset resultante

# %%
fatal_injuries_ML.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 221344 entries, 0 to 221343
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   id                             221344 non-null  int64
#  1   a_o_del_hecho                  221344 non-null  int64
#  2   sexo_de_la_victima             221344 non-null  object
#  3   grupo_de_edad_de_la_victima    221344 non-null  object
#  4   mes_del_hecho                  221344 non-null  object
#  5   dia_del_hecho                  221344 non-null  object
#  6   departamento_del_hecho_dane    221344 non-null  object
#  7   municipio_del_hecho_dane       221344 non-null  object
#  8   lesion_fatal_de_causa_externa  221344 non-null  object
#  9   estado                         221344 non-null  object
# dtypes: int64(2), object(8)
# memory usage: 16.9+ MB

# %% [markdown]
# ### Eliminación de columnas irrelevantes para el proyecto

# %%
relevant_cols = ['a_o_del_hecho', 'sexo_de_la_victima', 'grupo_de_edad_de_la_victima', 'departamento_del_hecho_dane', 'municipio_del_hecho_dane', 'lesion_fatal_de_causa_externa']
fatal_injuries_ML_ = fatal_injuries_ML[relevant_cols]
fatal_injuries_ML.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 221344 entries, 0 to 221343
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   id                             221344 non-null  int64
#  1   a_o_del_hecho                  221344 non-null  int64
#  2   sexo_de_la_victima             221344 non-null  object
#  3   grupo_de_edad_de_la_victima    221344 non-null  object
#  4   mes_del_hecho                  221344 non-null  object
#  5   dia_del_hecho                  221344 non-null  object
#  6   departamento_del_hecho_dane    221344 non-null  object
#  7   municipio_del_hecho_dane       221344 non-null  object
#  8   lesion_fatal_de_causa_externa  221344 non-null  object
#  9   estado                         221344 non-null  object
# dtypes: int64(2), object(8)
# memory usage: 16.9+ MB

# %%
# Años que incluye el dataset
fatal_injuries_ML_['a_o_del_hecho'].unique()
# Out:
# array([2023, 2024, 2021, 2022, 2020, 2016, 2017, 2018, 2019])

# %% [markdown]
# ### Verificar valores nulos

# %%
fatal_injuries_ML_.isnull().sum()
# Out:
# a_o_del_hecho                    0
# sexo_de_la_victima               0
# grupo_de_edad_de_la_victima      0
# departamento_del_hecho_dane      0
# municipio_del_hecho_dane         0
# lesion_fatal_de_causa_externa    0
# dtype: int64

# %% [markdown]
# ### Estandarización de categorizaciones
#
# La estandarización de categorizaciones es el proceso de uniformizar y normalizar los valores de las categorías en un conjunto de datos para asegurar la consistencia y evitar discrepancias. Esto es crucial para la calidad y precisión de los análisis

# %%
# Imprimir categorías únicas para columnas de tipo object
categorical_col = ['sexo_de_la_victima', 'grupo_de_edad_de_la_victima' ,'departamento_del_hecho_dane', 'municipio_del_hecho_dane', 'lesion_fatal_de_causa_externa']
for column in categorical_col:
    print(f"Categorías en la columna '{column}':")
    print(fatal_injuries_ML_[column].unique())
    print()
# Out:
# Categorías en la columna 'sexo_de_la_victima':
# ['Hombre' 'Mujer' 'Indeterminado']
#
# Categorías en la columna 'grupo_de_edad_de_la_victima':
# ['(15 a 17)' '(18 a 19)' '(20 a 24)' '(30 a 34)' '(70 a 74)' '(40 a 44)'
#  '(55 a 59)' '(25 a 29)' '(45 a 49)' '(00 a 04)' '(50 a 54)' '(35 a 39)'
#  '(60 a 64)' '(10 a 14)' '(65 a 69)' '(05 a 09)' '(80 y mas)' '(75 a 79)'
#  'Sin información' '(80 y más)' 'Por determinar' 'FETOS' 'Fetos']
#
# Categorías en la columna 'departamento_del_hecho_dane':
# ['Bogotá, D.C.' 'Tolima' 'Cundinamarca' 'Amazonas' 'Boyacá' 'Putumayo'
#  'Casanare' 'Meta' 'Chocó' 'Arauca' 'Norte de Santander' 'Caldas' 'Huila'
#  'Antioquia' 'Vichada' 'Vaupés'
#  'Archipiélago de San Andrés, Providencia y Santa Catalina' 'Atlántico'
#  'Guaviare' 'Valle del Cauca' 'Córdoba' 'Bolívar' 'Risaralda' 'Quindío'
#  'Sucre' 'Cesar' 'Sin información' 'Santander' 'La Guajira' 'Magdalena'
#  'Guainía' 'Caquetá' 'Cauca' 'Nariño' 'Sin Información']
#
# Categorías en la columna 'municipio_del_hecho_dane':
# ['Bogotá, D.C.' 'Espinal' 'Villa de San Diego de Ubaté' ... 'Pacoa'
#  'Cepitá' 'El Guamo']
#
# Categorías en la columna 'lesion_fatal_de_causa_externa':
# ['Violenta - Presuntos Homicidios' 'Violenta - Suicidios'
#  'Violenta - Muertes accidentales'
#  'Violenta - Muertes por eventos de transporte' 'Violenta - Homicidios'
#  'Violenta - Muertes en eventos de transporte'
#  'Violenta - Muertes en accidentes de transporte']

# %% [markdown]
# - Borrar espacios en blanco al principio y al final, cambiar a mayúsculas, remover acentos y eliminar signos extraños

# %%
import unicodedata

def remove_accents_and_special_chars(input_str):
    # Normalizar la cadena a NFKD
    nfkd_form = unicodedata.normalize('NFKD', input_str)

    # Eliminar acentos
    no_accents = ''.join([c for c in nfkd_form if not unicodedata.combining(c)])

    # Definir caracteres no deseados
    unwanted_chars = [',', ';', '!', '?', '#', '$', '%']

    # Eliminar caracteres no deseados
    cleaned_str = ''.join([c for c in no_accents if c not in unwanted_chars])

    # Remover espacios en blanco al principio y al final, y convertir a mayúsculas
    result = cleaned_str.strip().upper()

    return result

# %%
# Aplicar la función a todas las columnas categóricas
fatal_injuries_ML.loc[:,categorical_col] = fatal_injuries_ML_[categorical_col].astype(str)
for col in categorical_col:
    fatal_injuries_ML_.loc[:,col] = fatal_injuries_ML_[col].apply(remove_accents_and_special_chars)

# %% [markdown]
#   - Discretización de la variable grupo_de_edad_de_la_victima

# %%
# Funcion para categorizar
def categorize_age(range):
    if range in ['(00 A 04)', '(05 A 09)', '(10 A 14)']:
        return 'NIÑOS'
    elif range in ['(15 A 17)', '(18 A 19)', '(20 A 24)']:
        return 'JOVENES'
    elif range in ['(25 A 29)', '(30 A 34)', '(35 A 39)', '(40 A 44)', '(45 A 49)', '(50 A 54)', '(55 A 59)']:
        return 'ADULTOS'
    elif range in ['(60 A 64)', '(65 A 69)', '(70 A 74)', '(75 A 79)', '(80 Y MAS)']:
        return 'ADULTOS_MAYORES'
    else:
        return 'SIN INFORMACION'

# %%
# Aplicar funcion a columna
fatal_injuries_ML_.loc[:, 'victim_age'] = fatal_injuries_ML_['grupo_de_edad_de_la_victima'].apply(categorize_age)
fatal_injuries_ML_['victim_age'].unique()
# Out:
# <ipython-input-21-0dadcf323212>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fatal_injuries_ML_.loc[:, 'victim_age'] = fatal_injuries_ML_['grupo_de_edad_de_la_victima'].apply(categorize_age)
# array(['JOVENES', 'ADULTOS', 'ADULTOS_MAYORES', 'NIÑOS',
#        'SIN INFORMACION'], dtype=object)

# %% [markdown]
# - Normalizar y limpiar las categorias de la columna lesion_fatal_de_causa_externa

# %%
def clean_category(category):
    category = category.replace('VIOLENTA - ', '')
    category = category.replace('PRESUNTOS ', '')
    category = category.replace('MUERTES POR EVENTOS DE TRANSPORTE', 'MUERTES EN ACCIDENTES DE TRANSPORTE')
    return category

# Aplicar la función a la columna
fatal_injuries_ML_.loc[:,'lesion_fatal_de_causa_externa'] = fatal_injuries_ML_['lesion_fatal_de_causa_externa'].apply(clean_category)

# %% [markdown]
# ## Agregar código del municipio a dataframe fatal_injuries_ML_ para facilitar la georeferenciación
#
# ### -  Cargar los datos con códigos de departamentos y municipios
#
# Los códigos reales de los municipios de Colombia, están almacenados en la base de datos PostgreSQL del proyecto, en la tabla municipalities dentro del campo dept_mpio_code, junto con la informacion necesaria para georeferenciar todos los municipios y departamentos de Colombia. Este campo guarda el código del municipio en un formato string de exactamente 5 caracteres.
#
# Para hacer esta verificación, previamente exportamos desde la base de datos PostgreSQL un DataFrame con los siguientes campos: dept_name, mpio_name y dept_mpio_code, los cuales contienen la información de los departamentos y municipios oficiales, junto con sus respectivos códigos. Este DataFrame se carga en la siguiente celda y se utiliza para comparar con la columna "codigo_mpio"

# %%
dept_mpios_codes = pd.read_csv("/content/drive/MyDrive/analytics_data_proyect/deptos_mupios.csv", index_col=0, dtype={'dept_mpio_code': str})
print(dept_mpios_codes.info())
dept_mpios_codes.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1121 entries, 0 to 1120
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   dept_mpio_code  1121 non-null   object
#  1   dept_name       1121 non-null   object
#  2   mupio_name      1121 non-null   object
# dtypes: object(3)
# memory usage: 35.0+ KB
# None
#   dept_mpio_code dept_name mupio_name
# 0          97001    VAUPES       MITU
# 1          97161    VAUPES     CARURU
# 2          97511    VAUPES      PACOA
# 3          97666    VAUPES    TARAIRA
# 4          97777    VAUPES  PAPUNAHUA

# %% [markdown]
# ### -  Asegurarse de que los nombres de los departamentos estén escritos de manera identica en cada dataframe
#
#   - Borrar espacios en blanco al principio y al final, cambiar a mayúsculas, remover acentos y eliminar signos extraños

# %%
# Aplicar funcion a columnas 'dept_name', 'mupio_name'
for col in dept_mpios_codes[['dept_name', 'mupio_name']]:
    dept_mpios_codes[col] = dept_mpios_codes[col].apply(remove_accents_and_special_chars)

# %% [markdown]
# - Comparar que los nombres de los departamentos en cada dataframe esten escritos correctamente

# %%
# Función para comparar listas y mostrar diferencias
def compare_lists(df1_col, df2_col, label1, label2):
    # Extraer listas únicas y normalizar
    list1 = set(df1_col.str.strip().str.upper().unique())
    list2 = set(df2_col.str.strip().str.upper().unique())

    # Encontrar diferencias
    only_in_list1 = list1 - list2
    only_in_list2 = list2 - list1

    # Imprimir resultados
    print(f"{label1} que no están en {label2}:")
    print(only_in_list1)
    # print(f"{label2} que no están en {label1}:")
    # print(only_in_list2)
    # print()

# %% [markdown]
#   - Comparar nombres de departamentos en los dataframes

# %%
# Comparar listas de departamento
compare_lists(fatal_injuries_ML_['departamento_del_hecho_dane'], dept_mpios_codes['dept_name'],
              "Departamentos en fatal_injuries_ML_", "Departamentos dept_mpios_codes")
# Out:
# Departamentos en fatal_injuries_ML_ que no están en Departamentos dept_mpios_codes:
# {'SIN INFORMACION'}

# %%
# Verifcar registros sin información de departamentos
sin_inf = fatal_injuries_ML_[fatal_injuries_ML_['departamento_del_hecho_dane']== 'SIN INFORMACION']
print('Total registros:', len(sin_inf))
sin_inf.head()
# Out:
# Total registros: 117
#        a_o_del_hecho sexo_de_la_victima grupo_de_edad_de_la_victima  \
# 7933            2023              MUJER                   (15 A 17)
# 9505            2023             HOMBRE                   (50 A 54)
# 10117           2023             HOMBRE                   (20 A 24)
# 19332           2023             HOMBRE                   (20 A 24)
# 20011           2023             HOMBRE                   (25 A 29)
#
#       departamento_del_hecho_dane municipio_del_hecho_dane  \
# 7933              SIN INFORMACION          SIN INFORMACION
# 9505              SIN INFORMACION          SIN INFORMACION
# 10117             SIN INFORMACION          SIN INFORMACION
# 19332             SIN INFORMACION          SIN INFORMACION
# 20011             SIN INFORMACION          SIN INFORMACION
#
#       lesion_fatal_de_causa_externa victim_age
# 7933                      SUICIDIOS    JOVENES
# 9505                     HOMICIDIOS    ADULTOS
# 10117                     SUICIDIOS    JOVENES
# 19332                    HOMICIDIOS    JOVENES
# 20011                    HOMICIDIOS    ADULTOS

# %% [markdown]
# Nota: Por tratarse de un proyecto que enfatiza en la georreferencia no nos interesan datos de los que no se tenga el departamento, ni el municipio donde se produjo el hecho, por lo tanto borramos los registros "SIN INFORMACION" en la columna departamento

# %%
# Conservar únicamente las filas que tienen el departamento identificado
fatal_injuries_ML_ = fatal_injuries_ML_[fatal_injuries_ML_['departamento_del_hecho_dane'] != 'SIN INFORMACION']
len(fatal_injuries_ML_[fatal_injuries_ML_['departamento_del_hecho_dane'] == 'SIN INFORMACION'])
# Out:
# 0

# %% [markdown]
#  - Confirmar que discrepancia se solucionó

# %%
# Comparar listas de departamento
compare_lists(fatal_injuries_ML_['departamento_del_hecho_dane'], dept_mpios_codes['dept_name'],
              "Departamentos en fatal_injuries_ML_", "Departamentos dept_mpios_codes")
# Out:
# Departamentos en fatal_injuries_ML_ que no están en Departamentos dept_mpios_codes:
# set()

# %% [markdown]
#   b) Aplicar coincidencia difusa para combinacion departamento + municipio en los dos dataframe
#
# Realizar coincidencia difusa (fuzzy matching), significa que puede comparar dos cadenas de texto (strings) y medir su similitud, incluso si no son exactamente iguales. Esta técnica es muy útil en este caso porque si bien los nombres de los departamentos estan debidamente ajustados en los dos df,  los nombres de los municipios pueden tener diferencias (errores de tipeo, variantes en nombres, etc.).
#
# El utilizar la columna del nombre del departamento, es importante en este caso porque en colombia existen municipios con el mismo nombre.
#
#
#  - Instalar la thefuzz en el entorno de google colab, para realizar coincidencia difusa

# %%
# !pip install thefuzz
# Out:
# Requirement already satisfied: thefuzz in /usr/local/lib/python3.10/dist-packages (0.22.1)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from thefuzz) (3.10.0)

# %% [markdown]
# - Aplicar thefuzz para coincidencia difusa

# %%
# Crear una clave única de departamento + municipio en ambos datasets
fatal_injuries_ML_['dept_mpio'] = fatal_injuries_ML_['departamento_del_hecho_dane'] + '_' + fatal_injuries_ML_['municipio_del_hecho_dane']
dept_mpios_codes['dept_mpio'] = dept_mpios_codes['dept_name'] + '_' + dept_mpios_codes['mupio_name']

# %%
# Crear un diccionario de municipios y códigos basado en dept_mpios_codes
municipios_dict = dict(zip(dept_mpios_codes['dept_mpio'], dept_mpios_codes['dept_mpio_code']))

# %%
from thefuzz import process

# Funcion para Usar fuzzy matching (thefuzz)
def get_best_match(row, municipios_dict, threshold=80):
    dept_mpio_= row['departamento_del_hecho_dane'] + '_' + row['municipio_del_hecho_dane']

    # Buscar la mejor coincidencia en dept_mpios_codes usando fuzzy matching
    best_match, score = process.extractOne(dept_mpio_, municipios_dict.keys())

    # Si la similitud supera el umbral definido, devolver el código mapeado
    if score >= threshold:
        return municipios_dict[best_match]
    else:
        return 'SIN DATOS'

# %%
# Aplicar la función para encontrar la mejor coincidencia
fatal_injuries_ML_['codigo_dane'] = fatal_injuries_ML_.apply(
    lambda row: get_best_match(row, municipios_dict, threshold=80), axis=1)

# %% [markdown]
#   - Verificar resultados obtenidos

# %%
fatal_injuries_ML_.head()
# Out:
#    a_o_del_hecho sexo_de_la_victima grupo_de_edad_de_la_victima  \
# 0           2023             HOMBRE                   (15 A 17)
# 1           2023             HOMBRE                   (18 A 19)
# 2           2023             HOMBRE                   (20 A 24)
# 3           2023             HOMBRE                   (30 A 34)
# 4           2023             HOMBRE                   (20 A 24)
#
#   departamento_del_hecho_dane municipio_del_hecho_dane  \
# 0                 BOGOTA D.C.              BOGOTA D.C.
# 1                 BOGOTA D.C.              BOGOTA D.C.
# 2                 BOGOTA D.C.              BOGOTA D.C.
# 3                 BOGOTA D.C.              BOGOTA D.C.
# 4                 BOGOTA D.C.              BOGOTA D.C.
#
#   lesion_fatal_de_causa_externa victim_age                dept_mpio  \
# 0                    HOMICIDIOS    JOVENES  BOGOTA D.C._BOGOTA D.C.
# 1                    HOMICIDIOS    JOVENES  BOGOTA D.C._BOGOTA D.C.
# 2                    HOMICIDIOS    JOVENES  BOGOTA D.C._BOGOTA D.C.
# 3                    HOMICIDIOS    ADULTOS  BOGOTA D.C._BOGOTA D.C.
# 4                    HOMICIDIOS    JOVENES  BOGOTA D.C._BOGOTA D.C.
#
#   codigo_dane
# 0       11001
# 1       11001
# 2       11001
# 3       11001
# 4       11001

# %% [markdown]
# - Verificar que los códigos de municipios que quedaron en el dataset correspondan solamente a códigos reales

# %%
# Comparar listas de códigos
compare_lists(fatal_injuries_ML_['codigo_dane'], dept_mpios_codes['dept_mpio_code'],
              "Códigos de municipios en fatal_injuries_ML_", "Códigos de municipios dept_mpios_codes")
# Out:
# Códigos de municipios en fatal_injuries_ML_ que no están en Códigos de municipios dept_mpios_codes:
# {'SIN DATOS'}

# %%
# Verificar cuantos municipios quedaron sin código
len(fatal_injuries_ML_[fatal_injuries_ML_['codigo_dane']== 'SIN DATOS'])
# Out:
# 2

# %%
# Verificar cuales municipios quedaron sin código
fatal_injuries_ML_[fatal_injuries_ML_['codigo_dane']== 'SIN DATOS']
# Out:
#        a_o_del_hecho sexo_de_la_victima grupo_de_edad_de_la_victima  \
# 40682           2024             HOMBRE                   (25 A 29)
# 86321           2020             HOMBRE                   (55 A 59)
#
#       departamento_del_hecho_dane municipio_del_hecho_dane  \
# 40682                     GUAINIA               MAPIRIPANA
# 86321                     GUAINIA               MAPIRIPANA
#
#       lesion_fatal_de_causa_externa victim_age           dept_mpio codigo_dane
# 40682          MUERTES ACCIDENTALES    ADULTOS  GUAINIA_MAPIRIPANA   SIN DATOS
# 86321                    HOMICIDIOS    ADULTOS  GUAINIA_MAPIRIPANA   SIN DATOS

# %%
# Listado de municipios de Guania
dept_mpios_codes[dept_mpios_codes['dept_name'] == 'GUAINIA']
# Out:
#      dept_mpio_code dept_name       mupio_name                dept_mpio
# 1092          94001   GUAINIA          INIRIDA          GUAINIA_INIRIDA
# 1093          94343   GUAINIA    BARRANCOMINAS    GUAINIA_BARRANCOMINAS
# 1094          94883   GUAINIA       SAN FELIPE       GUAINIA_SAN FELIPE
# 1095          94884   GUAINIA  PUERTO COLOMBIA  GUAINIA_PUERTO COLOMBIA
# 1096          94885   GUAINIA     LA GUADALUPE     GUAINIA_LA GUADALUPE
# 1097          94886   GUAINIA         CACAHUAL         GUAINIA_CACAHUAL
# 1098          94887   GUAINIA        PANA PANA        GUAINIA_PANA PANA
# 1099          94888   GUAINIA         MORICHAL         GUAINIA_MORICHAL

# %%
# Como no hay ningun en Guania de nombre MAPIRIAPANA eliminamos esos 2 registros
fatal_injuries_ML_ = fatal_injuries_ML_[~(fatal_injuries_ML_['codigo_dane']== 'SIN DATOS')]

# %% [markdown]
#  - Verificar que los códigos de municipios que quedaron en el dataset correspondan solamente a códigos reales

# %%
# Comparar listas de códigos
compare_lists(fatal_injuries_ML_['codigo_dane'], dept_mpios_codes['dept_mpio_code'],
              "Códigos de municipios en fatal_injuries_ML_", "Códigos de municipios dept_mpios_codes")
# Out:
# Códigos de municipios en fatal_injuries_ML_ que no están en Códigos de municipios dept_mpios_codes:
# set()

# %% [markdown]
# ### Procesamiento final como preparación para integrarlo a la bd de datos del proyecto

# %%
# Eliminar columnas innecesarias
columns_to_drop = ['departamento_del_hecho_dane', 'municipio_del_hecho_dane', 'dept_mpio', 'grupo_de_edad_de_la_victima']
final_fatal_injuries_ML = fatal_injuries_ML_.drop(columns=columns_to_drop)

# %%
# Adicionar columna para trazabilidad de la fuente
final_fatal_injuries_ML['source_id_1'] = 38
final_fatal_injuries_ML['source_id_2'] = 39
final_fatal_injuries_ML['source_id_3'] = 40
final_fatal_injuries_ML['source_id_4'] = 41
final_fatal_injuries_ML['source_id_5'] = 42
final_fatal_injuries_ML['source_id_6'] = 43

# %%
final_fatal_injuries_ML.columns
# Out:
# Index(['a_o_del_hecho', 'sexo_de_la_victima', 'lesion_fatal_de_causa_externa',
#        'victim_age', 'codigo_dane', 'source_id_1', 'source_id_2',
#        'source_id_3', 'source_id_4', 'source_id_5', 'source_id_6'],
#       dtype='object')

# %%
# Ajustar nombre de columnas

# Definir el diccionario de traducción
translation_map = {
    'codigo_dane': 'dane_code',
    'a_o_del_hecho': 'year_of_incident',
    'sexo_de_la_victima': 'sex',
    'victim_age': 'age_group',
    'lesion_fatal_de_causa_externa': 'cause_of_death',
    'source_id_1': 'source_1',
    'source_id_2': 'source_2',
    'source_id_3': 'source_3',
    'source_id_4': 'source_4',
    'source_id_5': 'source_5',
    'source_id_6': 'source_6'
}

# Renombrar las columnas
final_fatal_injuries_ML.rename(columns=translation_map, inplace=True)

# %%
final_fatal_injuries_ML.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 221225 entries, 0 to 221343
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   year_of_incident  221225 non-null  int64
#  1   sex               221225 non-null  object
#  2   cause_of_death    221225 non-null  object
#  3   age_group         221225 non-null  object
#  4   dane_code         221225 non-null  object
#  5   source_1          221225 non-null  int64
#  6   source_2          221225 non-null  int64
#  7   source_3          221225 non-null  int64
#  8   source_4          221225 non-null  int64
#  9   source_5          221225 non-null  int64
#  10  source_6          221225 non-null  int64
# dtypes: int64(7), object(4)
# memory usage: 20.3+ MB

# %% [markdown]
# ## Salvar en archivo csv en el drive

# %%
# Guardar en archivos CSV en el drive
final_fatal_injuries_ML.to_csv('/content/drive/MyDrive/analytics_data_proyect/initial_transformation/fatal_injuries_ML.csv', index=False)
