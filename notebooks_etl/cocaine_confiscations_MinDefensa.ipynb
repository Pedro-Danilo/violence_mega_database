# %% [markdown]
# ###Fuente de la data
#
# Los micro-datos gestionados en este notebook son tomados de www.datos.gov.co y corresponden a datos cuya fuente primaria es el Ministerio de Defensa Nacional de Colombia

# %%
import pandas as pd

# %% [markdown]
# ###Archivo 26zg-9p9r.csv
#
# Contiene información sobre incautaciones cocaína.  Incluye el número de kilos de clorhidrato de cocaína incautado o interrumpido por la Fuerza Pública en el ejercicio de sus funciones. Entiéndase por Clorhidrato de cocaína como el producto obtenido a partir de la pasta básica de cocaína o base de cocaína mediante una serie de reacciones que incluyen cambios de pH y procesos de precipitación, para finalizar con la adición de ácido clorhídrico con el objeto de formar la sal. La unidad de medida corresponde a kilogramos incautados (kg).

# %%
df = pd.read_csv("https://www.datos.gov.co/resource/26zg-9p9r.csv?$limit=500000", dtype={'cod_muni': str})
df.head()
# Out:
# <ipython-input-11-c83d3d53fa28>:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("https://www.datos.gov.co/resource/26zg-9p9r.csv?$limit=500000", dtype={'cod_muni': str})
#                fecha_hecho cod_depto departamento cod_muni  \
# 0  2024-07-31T00:00:00.000        05    ANTIOQUIA    05040
# 1  2024-07-31T00:00:00.000        05    ANTIOQUIA    05148
# 2  2024-07-31T00:00:00.000        05    ANTIOQUIA    05001
# 3  2024-07-31T00:00:00.000        05    ANTIOQUIA    05001
# 4  2024-07-31T00:00:00.000        05    ANTIOQUIA    05001
#
#               municipio  cantidad     unidad
# 0                 ANORI    0.0100  KILOGRAMO
# 1  EL CARMEN DE VIBORAL    0.0172  KILOGRAMO
# 2              MEDELLIN    0.0250  KILOGRAMO
# 3              MEDELLIN    0.0970  KILOGRAMO
# 4              MEDELLIN    0.0052  KILOGRAMO

# %% [markdown]
# ##Revisión y limpieza para integrarlo a la base de datos
#
# ### - Resumen de la estructura del dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197074 entries, 0 to 197073
# Data columns (total 7 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   fecha_hecho   197074 non-null  object
#  1   cod_depto     197038 non-null  object
#  2   departamento  197074 non-null  object
#  3   cod_muni      197025 non-null  object
#  4   municipio     197074 non-null  object
#  5   cantidad      197074 non-null  float64
#  6   unidad        197074 non-null  object
# dtypes: float64(1), object(6)
# memory usage: 10.5+ MB

# %% [markdown]
# ### Eliminación de columnas irrelevantes para el proyecto

# %%
relevant_cols = ['cod_muni', 'departamento', 'municipio', 'fecha_hecho', 'cantidad', 'unidad']
cocaine_confiscations_MinDefensa = df[relevant_cols]
cocaine_confiscations_MinDefensa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197074 entries, 0 to 197073
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   cod_muni      197025 non-null  object
#  1   departamento  197074 non-null  object
#  2   municipio     197074 non-null  object
#  3   fecha_hecho   197074 non-null  object
#  4   cantidad      197074 non-null  float64
#  5   unidad        197074 non-null  object
# dtypes: float64(1), object(5)
# memory usage: 9.0+ MB

# %% [markdown]
# ### Convertir columna fecha_hecho a tipo date

# %%
# Hacer una copia explícita del DataFrame
cocaine_confiscations_MinDefensa_ = cocaine_confiscations_MinDefensa.copy()

# Convertir la columna 'fecha_hecho' a tipo datetime (sin especificar formato)
cocaine_confiscations_MinDefensa_['fecha_hecho'] = pd.to_datetime(cocaine_confiscations_MinDefensa_['fecha_hecho'], errors='coerce')

# Extraer solo el año
cocaine_confiscations_MinDefensa_['fecha_hecho'] = cocaine_confiscations_MinDefensa_['fecha_hecho'].dt.year

# %%
cocaine_confiscations_MinDefensa_['fecha_hecho'].unique()
# Out:
# array([2024, 2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014,
#        2013, 2012, 2011, 2010], dtype=int32)

# %% [markdown]
# ### Verificar valores nulos

# %%
cocaine_confiscations_MinDefensa_.isnull().sum()
# Out:
# cod_muni        49
# departamento     0
# municipio        0
# fecha_hecho      0
# cantidad         0
# unidad           0
# dtype: int64

# %% [markdown]
# Nota: Los nulos de 'cod_muni' los abordamos más adelante

# %% [markdown]
# ### Estandarización de categorizaciones
#
# La estandarización de categorizaciones es el proceso de uniformizar y normalizar los valores de las categorías en un conjunto de datos para asegurar la consistencia y evitar discrepancias. Esto es crucial para la calidad y precisión de los análisis

# %%
# Imprimir categorías únicas para columnas de tipo object
categorical_col = ['departamento', 'municipio', 'unidad']
for column in categorical_col:
    print(f"Categorías en la columna '{column}':")
    print(cocaine_confiscations_MinDefensa_[column].unique())
    print()
# Out:
# Categorías en la columna 'departamento':
# ['ANTIOQUIA' 'BOGOTÁ D.C.' 'CALDAS' 'CAQUETÁ' 'NARIÑO'
#  'NORTE DE SANTANDER' 'SANTANDER' 'VALLE DEL CAUCA' 'ATLÁNTICO' 'BOLÍVAR'
#  'CUNDINAMARCA' 'ESPAÑA' 'HUILA' 'PAISES BAJOS' 'QUINDÍO'
#  'REPUBLICA DOMINICANA' 'CHOCÓ' 'META' 'PANAMA' 'SAN ANDRÉS ISLAS'
#  'AGUAS INTERNACIONALES' 'LA GUAJIRA' 'RISARALDA' 'COSTA RICA' 'HONDURAS'
#  'MAGDALENA' 'PUERTO RICO' 'CESAR' 'CÓRDOBA' 'MEXICO' 'ARUBA' 'BELGICA'
#  'ECUADOR' 'PUTUMAYO' 'BOYACÁ' 'BRASIL' 'CASANARE' 'TOLIMA' 'CHILE'
#  'SUCRE' 'ANTILLAS NEERLANDESAS' 'ARAUCA' 'CAUCA'
#  'ESTADOS UNIDOS DE AMERICA' 'FRANCIA' 'EL SALVADOR' 'GUATEMALA'
#  'AMAZONAS' 'GUAINÍA' 'PERU' 'PORTUGAL' 'ISLAS VIRGENES BRITANICAS'
#  'VAUPÉS' 'INGLATERRA' 'MARTINICA' 'GUAYANA' 'VICHADA' 'BAHAMAS'
#  'VENEZUELA' 'GUAVIARE' 'LIBERIA' 'JAMAICA' 'CANADA' 'SURINAM' 'RUSIA'
#  'BOLIVAR' 'BOGOTA D.C.' 'CAQUETA' 'QUINDIO' 'ATLANTICO' 'CORDOBA'
#  'BOYACA' 'CHOCO' 'SAN ANDRES ISLAS' 'ITALIA' 'TURQUIA' 'REINO UNIDO'
#  'CABO VERDE' 'GUAINIA' 'GUINEA' 'VAUPES' 'NICARAGUA' 'ALEMANIA' 'CROACIA'
#  'UCRANIA' 'ANTILLAS HOLANDESAS' 'HOLANDA' 'CURAZAO' 'ESTADOS UNIDOS'
#  'SURINAN' 'RUMANIA' 'CUBA' 'ALBANIA' 'MALTA' 'MACEDONIA' 'BELICE'
#  'PARAGUAY' 'SUDÁFRICA' 'MAR PACÍFICO' 'CHINA' 'DINAMARCA'
#  'SIN ESTABLECER']
#
# Categorías en la columna 'municipio':
# ['ANORI' 'EL CARMEN DE VIBORAL' 'MEDELLIN' 'PUERTO BERRIO' 'RIONEGRO'
#  'SANTA ROSA DE OSOS' 'SANTO DOMINGO' 'BOGOTA, D.C.' 'SALAMINA'
#  'FLORENCIA' 'SAN ANDRES DE TUMACO' 'CUCUTA' 'VILLA DEL ROSARIO'
#  'BUCARAMANGA' 'FLORIDABLANCA' 'LA PAZ' 'BUENAVENTURA' 'PRADERA' 'SEVILLA'
#  'TRUJILLO' 'COPACABANA' 'BARRANQUILLA' 'CARTAGENA' 'ZAMBRANO' 'COTA'
#  'ESPAÑA' 'ALGECIRAS' 'IPIALES' 'PASTO' 'LOS PATIOS' 'PAISES BAJOS'
#  'ARMENIA' 'REPUBLICA DOMINICANA' 'BARBOSA' 'GIRON' 'SABANA DE TORRES'
#  'CALI' 'BELLO' 'CAUCASIA' 'SANTAFE DE ANTIOQUIA' 'ANSERMA' 'BAJO BAUDO'
#  'SOACHA' 'VIOTA' 'VILLAVICENCIO' 'OCAÑA' 'PANAMA' 'SAN ANDRES'
#  'PIEDECUESTA' 'AGUAS INTERNACIONALES' 'URRAO' 'MANIZALES'
#  'SAN JUAN DEL CESAR' 'PEREIRA' 'BARRANCABERMEJA' 'TULUA' 'LA ESTRELLA'
#  'SAN CARLOS' 'YOLOMBO' 'SAN JOSE' 'SAN VICENTE DEL CAGUAN' 'COSTA RICA'
#  'GIRARDOT' 'HONDURAS' 'RIOHACHA' 'CIENAGA' 'CUMARAL' 'GRANADA'
#  'PUERTO RICO' 'DOSQUEBRADAS' 'CARTAGO' 'ANDES' 'EL SANTUARIO'
#  'PUERTO COLOMBIA' 'CHINCHINA' 'VALLEDUPAR' 'MONTERIA' 'MOSQUERA'
#  'PUERTO LOPEZ' 'MEXICO' 'EL ZULIA' 'PAMPLONA' 'MONTENEGRO' 'LA VIRGINIA'
#  'GINEBRA' 'BETULIA' 'CISNEROS' 'GUARNE' 'ITAGUI' 'ARUBA' 'BELGICA'
#  'RISARALDA' 'FUQUENE' 'ECUADOR' 'HOBO' 'NEIVA' 'DIBULLA' 'FONSECA'
#  'EL BANCO' 'PUERTO LLERAS' 'MOCOA' 'CORDOBA' 'FILANDIA' 'APARTADO'
#  'ENVIGADO' 'LURUACO' 'SABANALARGA' 'MOMPOS' 'SOGAMOSO' 'VENTAQUEMADA'
#  'BRASIL' 'LA VEGA' 'TIMANA' 'SANTA BARBARA DE PINTO' 'SANTA MARTA'
#  'ABREGO' 'VALLE DEL GUAMUEZ' 'PUERTO WILCHES' 'CAJAMARCA' 'BUGALAGRANDE'
#  'AMAGA' 'SOPO' 'GUADALUPE' 'ARACATACA' 'BOCHALEMA' 'ESPINAL' 'RIOSUCIO'
#  'LA JAGUA DE IBIRICO' 'LA APARTADA' 'ACACIAS' 'YARUMAL'
#  'SAN JUAN NEPOMUCENO' 'LA DORADA' 'CHILE' 'SAHAGUN' 'NEMOCON'
#  'SAN LUIS DE PALENQUE' 'PLANETA RICA' 'SAMANIEGO' 'LOS SANTOS'
#  'ANSERMANUEVO' 'BURITICA' 'LA PINTADA' 'TITIRIBI' 'MARMATO' 'AGUACHICA'
#  'RIO DE ORO' 'ACANDI' 'AYAPEL' 'FUSAGASUGA' 'SAN JUAN DE ARAMA' 'APIA'
#  'DON MATIAS' 'ACHI' 'ARJONA' 'BARRANCO DE LOBA' 'CLEMENCIA' 'EL PEÑON'
#  'HATONUEVO' 'QUIMBAYA' 'SINCELEJO' 'ANTILLAS NEERLANDESAS' 'ARAUCA'
#  'RIO VIEJO' 'TOCAIMA' 'VILLETA' 'DISTRACCION' 'PUERTO GAITAN' 'QUINCHIA'
#  'CIMITARRA' 'FRESNO' 'YUMBO' 'CALDAS' 'SAN VICENTE' 'PENSILVANIA' 'SUPIA'
#  'YOPAL' 'FACATATIVA' 'SANTA ANA' 'SONSON' 'TADO' 'PALMIRA' 'VIJES'
#  'CONCORDIA' 'TAMESIS' 'URIBIA' 'EL RETEN' 'SAN CAYETANO' 'MARSELLA'
#  'LEBRIJA' 'COLOSO' 'CIUDAD BOLIVAR' 'TURBO' 'REGIDOR' 'PALESTINA' 'CHINU'
#  'AGRADO' 'CAMPOALEGRE' 'GARZON' 'ALBANIA' 'COROZAL' 'MADRID' 'CIRCASIA'
#  'SOLEDAD' 'PATIA' 'TOCANCIPA' 'ESTADOS UNIDOS DE AMERICA' 'FRANCIA'
#  'TELLO' 'DAGUA' 'MARINILLA' 'GALAPA' 'CALAMAR' 'MARIA LA BAJA' 'POPAYAN'
#  'MOMIL' 'EL SALVADOR' 'GUATEMALA' 'POTOSI' 'SAN GIL' 'GUACARI' 'SAN LUIS'
#  'SAN JACINTO' 'ORITO' 'GUADALAJARA DE BUGA' 'SABANETA' 'SANTA BARBARA'
#  'VILLA DE LEYVA' 'TIERRALTA' 'CALARCA' 'SOCORRO' 'PUERTO TEJADA'
#  'NOCAIMA' 'TIBU' 'LETICIA' 'VITERBO' 'BOSCONIA' 'VILLAGARZON'
#  'LA TEBAIDA' 'MISTRATO' 'ZARZAL' 'SABANAGRANDE' 'PLATO' 'LEGUIZAMO'
#  'VELEZ' 'SANTIAGO DE TOLU' 'YOTOCO' 'CARTAGENA DEL CHAIRA' 'CERETE'
#  'GUACA' 'DURANIA' 'PITALITO' 'BETANIA' 'CARACOLI' 'SAN ALBERTO'
#  'COLOMBIA' 'SANTIAGO' 'TORO' 'CAREPA' 'TURBACO' 'PUEBLO BELLO' 'VENECIA'
#  'MUZO' 'SANTANDER DE QUILICHAO' 'PITAL' 'FUNDACION' 'EL CASTILLO'
#  'BARBACOAS' 'ALVARADO' 'SAN BERNARDO DEL VIENTO' 'INIRIDA' 'LA UNION'
#  'SAN MARCOS' 'FLORIDA' 'GIRARDOTA' 'SAN RAFAEL' 'DUITAMA' 'AGUADAS'
#  'VERGARA' 'NATAGAIMA' 'SANTA ISABEL' 'CALIMA' 'LA CEJA' 'COTORRA'
#  'CHACHAGUI' 'SAN BERNARDO' 'PUERTO VLISSINGEN' 'IBAGUE' 'ENTRERRIOS'
#  'ZARAGOZA' 'SUAZA' 'SALENTO' 'PUENTE NACIONAL' 'ALBAN' 'GIGANTE'
#  'ABEJORRAL' 'VILLANUEVA' 'QUIBDO' 'CAQUEZA' 'PARATEBUENO' 'PERU' 'LERIDA'
#  'PALERMO' 'SANTA ROSA' 'MONTERREY' 'TORIBIO' 'LORICA' 'MONTELIBANO'
#  'SANDONA' 'CHIQUINQUIRA' 'MALLAMA' 'COVEÑAS' 'AMALFI' 'BUENAVISTA'
#  'LA PLATA' 'GUAMAL' 'JAMUNDI' 'LA VICTORIA' 'EL GUAMO' 'MIRAFLORES'
#  'QUEBRADANEGRA' 'BECERRIL' 'SUCRE' 'SALGAR' 'CHIMA' 'CAJICA' 'MAICAO'
#  'PORTUGAL' 'CHIGORODO' 'SAN ANDRES DE CUERQUIA' 'CHINACOTA'
#  'SAN JUAN DE BETULIA' 'CAICEDONIA' 'SAN CRISTOBAL' 'SAN AGUSTIN'
#  'CASTILLA LA NUEVA' 'ARBOLEDAS' 'SOLITA' 'EL TARRA' 'JERICO' 'EL PAUJIL'
#  'SEGOVIA' 'PUERTO ASIS' 'PUERTO GUZMAN' 'SANTA ROSA DE CABAL' 'EL AGUILA'
#  'HATO COROZAL' 'PUERTO SALGAR' 'TENJO' 'TERUEL' 'SANTACRUZ' 'ROLDANILLO'
#  'GOMEZ PLATA' 'SAN JOSE DEL FRAGUA' 'EL COLEGIO' 'SAN LUIS DE SINCE'
#  'VILLAMARIA' 'CHIMICHAGUA' 'MANAURE' 'SAN MIGUEL' 'BELEN DE UMBRIA'
#  'TOLU VIEJO' 'BARANOA' 'SOLANO' 'MAGANGUE' 'PUEBLO NUEVO' 'CANDELARIA'
#  'TRINIDAD' 'SILVANIA' 'ISLAS VIRGENES BRITANICAS' 'NECOCLI' 'CHAPARRAL'
#  'MITU' 'FUNZA' 'CONTADERO' 'GENOVA' 'PUERTO BOYACA' 'GUADUAS' 'LA PALMA'
#  'OBANDO' 'EL BAGRE' 'OLAYA' 'EL CARMEN DE BOLIVAR' 'MOÑITOS' 'RIVERA'
#  'INGLATERRA' 'MARTINICA' 'SUESCA' 'BARRANCA DE UPIA' 'LOS PALMITOS'
#  'SAN PEDRO' 'SOPETRAN' 'LA CALERA' 'SACAMA' 'CHIRIGUANA' 'GACHANCIPA'
#  'CHITAGA' 'SAN BENITO ABAD' 'PAMPLONITA' 'PACORA' 'LINARES' 'NEIRA'
#  'GUARANDA' 'MONTEBELLO' 'EL DONCELLO' 'GUAYANA' 'TENERIFE' 'SAMPUES'
#  'PUEBLORRICO' 'SIMACOTA' 'COCORNA' 'ITUANGO' 'MANATI' 'ZONA BANANERA'
#  'CACOTA' 'AGUAZUL' 'ZIPAQUIRA' 'ISNOS' 'AGUSTIN CODAZZI' 'SAN MARTIN'
#  'MOGOTES' 'MALAMBO' 'SAN SEBASTIAN DE BUENAVISTA' 'RESTREPO' 'TUNJA'
#  'BAHIA SOLANO' 'CABUYARO' 'PUERTO TRIUNFO' 'TUQUERRES' 'RAGONVALIA'
#  'LA MESA' 'PEÑOL' 'MORELIA' 'UNION PANAMERICANA' 'SITIONUEVO' 'EL PLAYON'
#  'OIBA' 'PUERTO CARREÑO' 'MAHATES' 'LA PRIMAVERA' 'YALI' 'BELALCAZAR'
#  'CHIA' 'AIPE' 'ILES' 'SAN PABLO' 'SARAVENA' 'CERRO SAN ANTONIO'
#  'PUEBLOVIEJO' 'SAN ZENON' 'SANTUARIO' 'MANZANARES' 'PIENDAMO' 'SIBATE'
#  'BARRANCAS' 'CUMBAL' 'MARQUETALIA' 'PUERTO CAICEDO' 'ALTAMIRA' 'CUASPUD'
#  'SALDAÑA' 'EL CERRITO' 'EL CARMEN DE CHUCURI' 'BOLIVAR' 'SUAN' 'VICTORIA'
#  'ARBOLEDA' 'PORE' 'IMUES' 'EBEJICO' 'CAPARRAPI' 'BARAYA' 'ANGELOPOLIS'
#  'SAN ROQUE' 'YONDO' 'PUPIALES' 'SAN FRANCISCO' 'MARIQUITA' 'LA CUMBRE'
#  'ANZA' 'BAHAMAS' 'TIMBIO' 'HELICONIA' 'MUTATA' 'MEDINA' 'RICAURTE'
#  'NECHI' 'SOPLAVIENTO' 'TAURAMENA' 'EL COPEY' 'NORCASIA' 'CHIBOLO'
#  'EL TAMBO' 'PUEBLO RICO' 'PALMAR DE VARELA' 'PONEDERA' 'GUAITARILLA'
#  'PROVIDENCIA' 'PUERRES' 'LA ESPERANZA' 'SUTAMARCHAN' 'LANDAZURI'
#  'LA MERCED' 'VILLA DE SAN DIEGO DE UBATE' 'BELEN DE LOS ANDAQUIES'
#  'PAZ DE ARIPORO' 'AGUA DE DIOS' 'EL ROSAL' 'ACEVEDO' 'EL CHARCO'
#  'TAMALAMEQUE' 'CHOCONTA' 'TESALIA' 'ARGELIA' 'PUERTO NARE'
#  'SAN JUAN DE RIO SECO' 'POLICARPA' 'CONVENCION' 'GUATAPE' 'ARIGUANI'
#  'PUERTO SANTANDER' 'GARAGOA' 'BUESACO' 'LA CRUZ' 'VILLA RICA' 'GUACHUCAL'
#  'LA TOLA' 'PELAYA' 'CUMBITARA' 'GUALMATAN' 'SIBUNDOY' 'FREDONIA' 'MORROA'
#  'ALTO BAUDO' 'BELMIRA' 'OTANCHE' 'LA ARGENTINA' 'SAN ONOFRE' 'ROVIRA'
#  'SAN JERONIMO' 'BALBOA' 'ANAPOIMA' 'VENEZUELA' 'BOJACA'
#  'PIJIÑO DEL CARMEN' 'OLAYA HERRERA' 'MALAGA' 'COGUA' 'LA SIERRA'
#  'VEGACHI' 'SAN ESTANISLAO' 'JURADO' 'REMEDIOS' 'CARMEN DE APICALA'
#  'VIANI' 'EL RETORNO' 'CAIMITO' 'NATAGA' 'CHARALA'
#  'SAN VICENTE DE CHUCURI' 'VALDIVIA' 'JUAN DE ACOSTA' 'SAN MARTIN DE LOBA'
#  'LIBERIA' 'CONCEPCION' 'JAMAICA' 'SAN ANTERO' 'MACEO' 'TAME' 'CERRITO'
#  'ZAPATOCA' 'FLANDES' 'BELEN' 'SANTA CATALINA' 'ARANZAZU' 'CANADA'
#  'BITUIMA' 'EL TABLON DE GOMEZ' 'MACHETA' 'CANTAGALLO' 'CIENAGA DE ORO'
#  'ALCALA' 'VALPARAISO' 'SAN JOSE DEL GUAVIARE' 'TARAZA' 'PEDRAZA'
#  'EL DOVIO' 'CURUMANI' 'TIQUISIO' 'SALAZAR' 'NUEVA GRANADA' 'EL PEÑOL'
#  'SANTA MARIA' 'TARSO' 'CANALETE' 'GUATAQUI' 'SURINAM' 'TALAIGUA NUEVO'
#  'GUACHENE' 'VALENCIA' 'QUIPILE' 'RUSIA' 'SAN JOSE DE URE' 'JARDIN'
#  'LA PEÑA' 'SARDINATA' 'HONDA' 'SANTA ROSALIA' 'EL PASO' 'MATANZA'
#  'LA FLORIDA' 'SAPUYES' 'PIJAO' 'VETAS' 'SANTO TOMAS' 'CICUCO'
#  'EL CARMEN DE ATRATO' 'CAPITANEJO' 'ULLOA' 'NILO' 'BUENOS AIRES'
#  'LOS CORDOBAS' 'LOS ANDES' 'MAJAGUAL' 'PLANADAS' 'LEJANIAS' 'EL CAIRO'
#  'FUNES' 'LA LLANADA' 'SIMITI' 'CORINTO' 'PURISIMA' 'ARATOCA' 'POLONUEVO'
#  'TAMINANGO' 'CALIFORNIA' 'SANTA ROSA DEL SUR' 'TUCHIN' 'CURILLO' 'SURATA'
#  'RETIRO' 'GALERAS' 'ALDANA' 'FRONTINO' 'BARICHARA' 'SAN ANDRES SOTAVENTO'
#  'GIRALDO' 'TIMBIQUI' 'CARTAGENA DE INDIAS' 'BOGOTA D.C.'
#  'SAN VICENTE FERRER' 'SAN JACINTO DEL CAUCA' 'DONMATIAS' 'MAPIRIPAN'
#  'CUMARIBO' 'PIVIJAY' 'SANTA CRUZ DE MOMPOX' 'ANGOSTURA' 'NUQUI' 'GÜEPSA'
#  'SAN LORENZO' 'CRAVO NORTE' 'PUERTO PARRA' 'ITALIA' 'TURQUIA'
#  'REINO UNIDO' 'TOLEDO' 'TEORAMA' 'PACHO' 'VENADILLO' 'PAILITAS' 'NARIÑO'
#  'SAN JUAN DE RIOSECO' 'GUAPI' 'OSPINA' 'SAN SEBASTIAN DE MARIQUITA'
#  'SUBACHOQUE' 'CABO VERDE' 'PIENDAMO - TUNIA' 'SUAREZ' 'GAMA'
#  'SANTA FE DE ANTIOQUIA' 'CALOTO' 'MOTAVITA' 'UBALA' 'TABIO' 'CHAGUANI'
#  'GUINEA' 'VALLE DE SAN JUAN' 'SAN JOSE DE TOLUVIEJO' 'SALADOBLANCO'
#  'PIAMONTE' 'PARAMO' 'GUAMO' 'PAICOL' 'SAMANA' 'TIBACUY' 'OVEJAS' 'PURACE'
#  'CARAMANTA' 'GUATICA' 'CAMPOHERMOSO' 'URUMITA' 'SAN PEDRO DE URABA'
#  'ARBOLETES' 'FORTUL' 'REPELON' 'PUERTO CONCORDIA' 'PIEDRAS' 'NICARAGUA'
#  'PIOJO' 'VISTAHERMOSA' 'GUAVATA' 'SUSA' 'CHIVOLO' 'TOPAIPI' 'ALEMANIA'
#  'PURISIMA DE LA CONCEPCION' 'MEDIO BAUDO' 'CARMEN DEL DARIEN' 'OROCUE'
#  'FILADELFIA' 'SOMONDOCO' 'PUERTO LIBERTADOR' 'DOLORES'
#  'SAN JOSE DE MIRANDA' 'ARROYOHONDO' 'TONA' 'GACHALA' 'LOURDES'
#  'PURIFICACION' 'LENGUAZAQUE' 'UTICA' 'GUAYABETAL' 'ROBERTO PAYAN' 'APULO'
#  'INZA' 'CAICEDO' 'SAN CARLOS DE GUAROA' 'ANZOATEGUI' 'CACERES'
#  'MANAURE BALCON DEL CESAR' 'COYAIMA' 'EL PIÑON' 'FUENTE DE ORO' 'TURBANA'
#  'CHARTA' 'SAN JUAN DE URABA' 'PUERTO ESCONDIDO' 'SAN JOSE DE LA MONTAÑA'
#  'LA MONTAÑITA' 'SAN DIEGO' 'GUTIERREZ' 'HERVEO' 'HERRAN' 'PALMITO'
#  'SAN ANDRES DE SOTAVENTO' 'ANDALUCIA' 'CAJIBIO' 'CAÑASGORDAS' 'LIBANO'
#  'SAN PELAYO' 'ISTMINA' 'CROACIA' 'CHACHAGÜI' 'EL ROSARIO'
#  'PUERTO LEGUIZAMO' 'LA JAGUA DEL PILAR' 'GUAYABAL DE SIQUIMA' 'UCRANIA'
#  'CAROLINA' 'MELGAR' 'QUETAME' 'MIRANDA' 'CUASPUD CARLOSAMA' 'CURITI'
#  'PADILLA' 'HACARI' 'YACUANQUER' 'ANCUYA' 'MACANAL' 'DABEIBA'
#  'SAN PEDRO DE LOS MILAGROS' 'SUTATAUSA' 'ANOLAIMA' 'TENA' 'MUTISCUA'
#  'MANI' 'AGUAS JURISDICCIONALES' 'MERCADERES' 'ANTILLAS HOLANDESAS'
#  'HOLANDA' 'CURAZAO' 'ESTADOS UNIDOS' 'VALLE DE SAN JOSE' 'CAMPAMENTO'
#  'PALOCABILDO' 'SILOS' 'SIPI' 'OCAMONTE' 'EL DORADO' 'CACHIRA' 'CONSACA'
#  'SURINAN' 'CUBARRAL' 'ARMERO' 'CASABIANCA' 'RIOFRIO'
#  'EL LITORAL DEL SAN JUAN' 'SASAIMA' 'RUMANIA' 'DOVER' 'EL CARMEN'
#  'NOROSI' 'GACHETA' 'SAN ANTONIO' 'HATILLO DE LOBA' 'CONFINES' 'HISPANIA'
#  'REMOLINO' 'CHIVATA' 'ROSAS' 'LA HABANA' 'ARAUQUITA' 'YAGUARA' 'SIMIJACA'
#  'CAMPO DE LA CRUZ' 'MALTA' 'TUBARA' 'CHIPAQUE' 'LA GLORIA' 'SANTA LUCIA'
#  'SAN PABLO DE BORBUR' 'LA MACARENA' 'MACEDONIA' 'ALGARROBO' 'PAIPA'
#  'GUASCA' 'UNGUIA' 'CHALAN' 'LA PLAYA' 'GUATEQUE' 'PEQUE' 'NUNCHIA'
#  'VERSALLES' 'BUCARASICA' 'GAMARRA' 'IQUIRA' 'BELICE' 'COLON'
#  'FRANCISCO PIZARRO' 'ALEJANDRIA' 'CHOACHI' 'USIACURI' 'LA CELIA'
#  'COMBITA' 'CACHIPAY' 'OPORAPA' 'MORALES' 'ATRATO' 'LOPEZ' 'MIAMI' 'TUTA'
#  'ASTREA' 'VIGIA DEL FUERTE' 'BOJAYA' 'RIO QUITO' 'BRICEÑO' 'RIOBLANCO'
#  'ARBELAEZ' 'LIBORINA' 'CUNDAY' 'CHAMEZA' 'TARQUI' 'PARAGUAY' 'SUDÁFRICA'
#  'ZAPAYAN' 'MEDIO ATRATO' 'GUACHETA' 'AMBALEMA' 'CUBARA' 'MONTECRISTO'
#  'CONDOTO' 'PAEZ' 'SAN CALIXTO' 'BARRANCO MINAS' 'BELTRAN' 'LLORO'
#  'CARMEN DE CARUPA' 'PUERTO NARIÑO' 'EL MOLINO' 'MURINDO'
#  'SAN ANTONIO DEL TEQUENDAMA' 'CALDONO' 'CERTEGUI' 'EL ROBLE'
#  'MAR PACÍFICO' 'SESQUILE' 'VILLA CARO' 'ABRIAQUI' 'ENCISO' 'TANGUA'
#  'JUNIN' 'TAUSA' 'URAMITA' 'SOCHA' 'FALAN' 'SAMACA' 'CHINA' 'TOTORO'
#  'SOTARA' 'PAIME' 'SUPATA' 'MONIQUIRA' 'MILAN' 'SACHICA' 'JAMBALO'
#  'CUCUNUBA' 'MURILLO' 'TUNUNGUA' 'TIPACOQUE' 'BAGADO'
#  'SANTA ROSA DE VITERBO' 'VILLAPINZON' 'ATACO' 'FOMEQUE' 'FOSCA' 'UNE'
#  'SAN JOSE DE PARE' 'GUATAVITA' 'PANDI' 'UBAQUE' 'JENESANO' 'CABRERA'
#  'MANTA' 'GRAMALOTE' 'EL ENCANTO' 'MARULANDA' 'ALMAGUER'
#  'ALTOS DEL ROSARIO' 'SUAITA' 'TARAPACA' 'YACOPI' 'NIMAIMA' 'GONZALEZ'
#  'PINCHOTE' 'NOVITA' 'IZA' 'TIBIRITA' 'COROMORO' 'ELIAS'
#  'SANTA HELENA DEL OPON' 'ARENAL' 'SAN JOSE DEL PALMAR' 'PASCA' 'ARCABUCO'
#  'NOBSA' 'COELLO' 'SOATA' 'SABANAS DE SAN ANGEL' 'ZIPACON' 'VILLAVIEJA'
#  'EL GUACAMAYO' 'SAN MATEO' 'COPER' 'RONCESVALLES' 'MESETAS' 'MARGARITA'
#  'PALMAS DEL SOCORRO' 'ALMEIDA' 'ORTEGA' 'PAUNA' 'SAN LUIS DE GACENO'
#  'PRADO' 'PUERTO RONDON' 'JERUSALEN' 'LA BELLEZA' 'GUAYATA' 'MAGUI' 'PULI'
#  'TIBASOSA' 'PAJARITO' 'AARHUS' 'SILVIA' 'SIN ESTABLECER' 'ICONONZO'
#  'CUCUTILLA' 'BOYACA' 'RECETOR' 'CARURU' 'LEIVA']
#
# Categorías en la columna 'unidad':
# ['KILOGRAMO']

# %% [markdown]
# - Borrar espacios en blanco al principio y al final, cambiar a mayúsculas, remover acentos y eliminar signos extraños

# %%
import unicodedata

def remove_accents_and_special_chars(input_str):
    # Normalizar la cadena a NFKD
    nfkd_form = unicodedata.normalize('NFKD', input_str)

    # Eliminar acentos
    no_accents = ''.join([c for c in nfkd_form if not unicodedata.combining(c)])

    # Definir caracteres no deseados
    unwanted_chars = [',', ';', '!', '?', '#', '$', '%']

    # Eliminar caracteres no deseados
    cleaned_str = ''.join([c for c in no_accents if c not in unwanted_chars])

    # Remover espacios en blanco al principio y al final, y convertir a mayúsculas
    result = cleaned_str.strip().upper()

    return result

# %%
# Aplicar la función a todas las columnas categóricas
cocaine_confiscations_MinDefensa_[categorical_col] = cocaine_confiscations_MinDefensa_[categorical_col].astype(str)
for col in categorical_col:
    cocaine_confiscations_MinDefensa_[col] = cocaine_confiscations_MinDefensa_[col].apply(remove_accents_and_special_chars)

# %% [markdown]
# - Codificación de algunas variables categóricas

# %% [markdown]
# ### Verificar que los valores en "cod_muni" coincidan con los códigos reales de municipios
#
# Los códigos reales de los municipios de Colombia, están almacenados en la base de datos PostgreSQL del proyecto, en la tabla municipalities dentro del campo dept_mpio_code, junto con la informacion necesaria para georeferenciar todos los municipios y departamentos de Colombia. Este campo guarda el código del municipio en un formato string de exactamente 5 caracteres.
#
# Para hacer esta verificación, previamente exportamos desde la base de datos PostgreSQL un DataFrame con los siguientes campos: dept_name, mpio_name y dept_mpio_code, los cuales contienen la información de los departamentos y municipios oficiales, junto con sus respectivos códigos. Este DataFrame se carga en la siguiente celda y se utiliza para comparar con la columna "codigo_mpio"

# %%
dept_mpios_codes = pd.read_csv("/content/drive/MyDrive/analytics_data_proyect/deptos_mupios.csv", index_col=0, dtype={'dept_mpio_code': str})
print(dept_mpios_codes.info())
dept_mpios_codes.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1121 entries, 0 to 1120
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   dept_mpio_code  1121 non-null   object
#  1   dept_name       1121 non-null   object
#  2   mupio_name      1121 non-null   object
# dtypes: object(3)
# memory usage: 35.0+ KB
# None
#   dept_mpio_code dept_name mupio_name
# 0          97001    VAUPES       MITU
# 1          97161    VAUPES     CARURU
# 2          97511    VAUPES      PACOA
# 3          97666    VAUPES    TARAIRA
# 4          97777    VAUPES  PAPUNAHUA

# %% [markdown]
#  -  Verificar la consistencia de la columna "cod_muni" en el df cocaine_confiscations_MinDefensa_

# %%
# Asegurarnos de que todos los valores en 'codigo_m' sean strings
cocaine_confiscations_MinDefensa_['cod_muni'] = cocaine_confiscations_MinDefensa_['cod_muni'].astype(str)

# Calcular la longitud de cada valor en la columna
longitudes = cocaine_confiscations_MinDefensa_['cod_muni'].apply(len)

# Verificar si todas las longitudes son iguales
longitudes.nunique() == 1
# Out:
# False

# %%
# Mostrar longitudes únicas (opcional)
print(f"Longitudes únicas: {longitudes.unique()}")
# Out:
# Longitudes únicas: [5 7 4 6 2 3 1]

# %%
# Contar registros por longitud
long_df = longitudes.value_counts().reset_index()
long_df.rename(columns={'codigo_dane': 'no_dígitos_codigo_dane'}, inplace=True)
long_df['percentage'] = (long_df['count'] / len(longitudes))
long_df.head()
# Out:
#    cod_muni   count  percentage
# 0         5  194492    0.986898
# 1         6    1047    0.005313
# 2         7     964    0.004892
# 3         4     298    0.001512
# 4         3     206    0.001045

# %%
# Mostrar una muestra de registros para cada longitud
for longitud in longitudes.value_counts().index:
    print(f"Muestra de registros con longitud {longitud}:")
    muestra = cocaine_confiscations_MinDefensa_[longitudes == longitud].head(5)  # Muestra de los primeros 5 registros
    print(muestra[['cod_muni']])
    print()
# Out:
# Muestra de registros con longitud 5:
#   cod_muni
# 0    05040
# 1    05148
# 2    05001
# 3    05001
# 4    05001
#
# Muestra de registros con longitud 6:
#      cod_muni
# 219    560101
# 281    560101
# 285    760101
# 385    760101
# 2036   920101
#
# Muestra de registros con longitud 7:
#    cod_muni
# 46  7240101
# 51  5280101
# 54  2140101
# 55  2140101
# 99  5910101
#
# Muestra de registros con longitud 4:
#      cod_muni
# 108      1111
# 434      1111
# 1394     1111
# 1544     1111
# 1857     1111
#
# Muestra de registros con longitud 3:
#       cod_muni
# 19339      504
# 19342      593
# 19354      502
# 19356      593
# 19367      507
#
# Muestra de registros con longitud 2:
#       cod_muni
# 19306       52
# 19316       52
# 19368       52
# 19369       55
# 19590       52
#
# Muestra de registros con longitud 1:
#       cod_muni
# 24404        7

# %%
# Verificar longitudes de 'cod_mupi' igual a 6 dígitos
cod_muni_6 = cocaine_confiscations_MinDefensa_[cocaine_confiscations_MinDefensa_['cod_muni'].apply(len) == 6]
cod_muni_6['departamento'].value_counts()
# Out:
# departamento
# PANAMA                       444
# COSTA RICA                   288
# ECUADOR                      150
# HONDURAS                      40
# EL SALVADOR                   30
# ESTADOS UNIDOS                24
# ANTILLAS HOLANDESAS           11
# BELGICA                       11
# NICARAGUA                      9
# ARUBA                          8
# BRASIL                         8
# PUERTO RICO                    6
# BAHAMAS                        5
# PORTUGAL                       5
# BELICE                         4
# ISLAS VIRGENES BRITANICAS      2
# PARAGUAY                       1
# ALBANIA                        1
# Name: count, dtype: int64

# %%
# Verificar longitudes de 'cod_mupi' igual a 7 dígitos
cod_muni_7 = cocaine_confiscations_MinDefensa_[cocaine_confiscations_MinDefensa_['cod_muni'].apply(len) == 7]
cod_muni_7['departamento'].value_counts()
# Out:
# departamento
# REPUBLICA DOMINICANA         245
# PANAMA                       138
# GUATEMALA                    131
# ESPANA                        76
# ECUADOR                       67
# MEXICO                        48
# COSTA RICA                    43
# PUERTO RICO                   29
# FRANCIA                       27
# ARUBA                         24
# ESTADOS UNIDOS DE AMERICA     18
# INGLATERRA                    15
# JAMAICA                       14
# ANTILLAS NEERLANDESAS         11
# PAISES BAJOS                  10
# HONDURAS                       9
# PERU                           9
# EL SALVADOR                    8
# VENEZUELA                      8
# REINO UNIDO                    5
# PORTUGAL                       4
# ITALIA                         4
# SURINAM                        2
# TURQUIA                        2
# RUSIA                          2
# CANADA                         2
# CHILE                          2
# GUAYANA                        2
# MARTINICA                      2
# LIBERIA                        1
# CABO VERDE                     1
# GUINEA                         1
# NICARAGUA                      1
# ALEMANIA                       1
# CROACIA                        1
# UCRANIA                        1
# Name: count, dtype: int64

# %%
# Verificar longitudes de 'cod_mupi' igual a 4 dígitos
cod_muni_4 = cocaine_confiscations_MinDefensa_[cocaine_confiscations_MinDefensa_['cod_muni'].apply(len) == 4]
cod_muni_4['departamento'].value_counts()
# Out:
# departamento
# AGUAS INTERNACIONALES    117
# REPUBLICA DOMINICANA      99
# MAR PACIFICO              54
# INGLATERRA                13
# FRANCIA                    9
# VENEZUELA                  3
# JAMAICA                    1
# RUMANIA                    1
# CHINA                      1
# Name: count, dtype: int64

# %%
# Verificar longitudes de 'cod_mupi' igual a 3 dígitos
cod_muni_3 = cocaine_confiscations_MinDefensa_[cocaine_confiscations_MinDefensa_['cod_muni'].apply(len) == 3]
cod_muni_3['departamento'].value_counts()
# Out:
# departamento
# PANAMA            75
# SIN ESTABLECER    26
# ECUADOR           22
# COSTA RICA        21
# EL SALVADOR       10
# PUERTO RICO        9
# ESTADOS UNIDOS     9
# HONDURAS           6
# GUATEMALA          6
# ALEMANIA           5
# PORTUGAL           4
# BAHAMAS            3
# SURINAN            2
# CHILE              1
# VENEZUELA          1
# ALBANIA            1
# MALTA              1
# PERU               1
# MACEDONIA          1
# CANADA             1
# INGLATERRA         1
# Name: count, dtype: int64

# %%
# Verificar longitudes de 'cod_mupi' igual a 2 dígitos
cod_muni_2 = cocaine_confiscations_MinDefensa_[cocaine_confiscations_MinDefensa_['cod_muni'].apply(len) == 2]
cod_muni_2['departamento'].value_counts()
# Out:
# departamento
# MEXICO          31
# ESPANA          21
# PAISES BAJOS     6
# BELGICA          3
# BRASIL           2
# RUMANIA          2
# ITALIA           1
# Name: count, dtype: int64

# %%
# Verificar longitudes de 'cod_mupi' igual a 1 dígito
cod_muni_1 = cocaine_confiscations_MinDefensa_[cocaine_confiscations_MinDefensa_['cod_muni'].apply(len) == 1]
cod_muni_1['departamento'].value_counts()
# Out:
# departamento
# CUBA    1
# Name: count, dtype: int64

# %% [markdown]
# Nota: Como se aprecia los 'cod_mun' con longitudes diferentes a 5 dígitos, que en total suman 2.515 registros de un total de 197.074, corresponden a incautaciones hechas en el exterior. Procedemos a excluirlas porque para efectos del proyecto no son importantes

# %%
cocaine_confiscations_MinDefensa_ = cocaine_confiscations_MinDefensa_[cocaine_confiscations_MinDefensa_['cod_muni'].apply(len) == 5]

# %% [markdown]
# Nota: Con el filtro anterior el 100%  de los codigos que identifican a los municipios en el df cocaine_confiscations_MinDefensa corresponden a string de 5 caracteres, igual a los almacenados en la base de datos del proyecto

# %% [markdown]
# - Comparar que los nombres de los departamentos en cada dataframe esten escritos correctamente
#
# Se aplica la función para racionalizar columnas categoricas (Borrar espacios en blanco al principio y al final, cambiar a mayúsculas, remover acentos y eliminar signos extraños) al df 'dept_mpiios_codes'

# %%
# Aplicar función a columnas 'dept_name', 'mupio_name'
for col in dept_mpios_codes[['dept_name', 'mupio_name']]:
    dept_mpios_codes[col] = dept_mpios_codes[col].apply(remove_accents_and_special_chars)

# %%
# Función para comparar listas y mostrar diferencias
def compare_lists(df1_col, df2_col, label1, label2):
    # Extraer listas únicas y normalizar
    list1 = set(df1_col.str.strip().str.upper().unique())
    list2 = set(df2_col.str.strip().str.upper().unique())

    # Encontrar diferencias
    only_in_list1 = list1 - list2
    only_in_list2 = list2 - list1

    # Imprimir resultados
    print(f"{label1} que no están en {label2}:")
    print(only_in_list1)
    # print(f"{label2} que no están en {label1}:")
    # print(only_in_list2)
    # print()

# %% [markdown]
#   - Comparar nombres de departamentos en los dataframes

# %%
# Comparar listas de departamento
compare_lists(cocaine_confiscations_MinDefensa_['departamento'], dept_mpios_codes['dept_name'],
              "Departamentos en cocaine_confiscations_MinDefensa_", "Departamentos dept_mpios_codes")
# Out:
# Departamentos en cocaine_confiscations_MinDefensa_ que no están en Departamentos dept_mpios_codes:
# {'ITALIA', 'VENEZUELA', 'DINAMARCA', 'CURAZAO', 'CROACIA', 'ALEMANIA', 'INGLATERRA', 'SUDAFRICA', 'PERU', 'ANTILLAS HOLANDESAS', 'FRANCIA', 'PORTUGAL', 'ARUBA', 'BELGICA', 'HOLANDA', 'MEXICO', 'ESPANA', 'SAN ANDRES ISLAS', 'BRASIL'}

# %% [markdown]
#   Nota: Aún figuran en el df incautaciones hechas en el exterior: 'ITALIA', 'VENEZUELA', 'DINAMARCA', 'CURAZAO', 'CROACIA', 'ALEMANIA', 'INGLATERRA', 'SUDAFRICA', 'PERU', 'ANTILLAS HOLANDESAS', 'FRANCIA', 'PORTUGAL', 'ARUBA', 'BELGICA', 'HOLANDA', 'MEXICO', 'ESPANA', 'BRASIL', además el departamento SAN ANDRES ISLAS está escrito en forma diferente a su nombre real
#
#   - Solucionar discrepancias en nombres de departamento SAN ANDRES ISLAS

# %%
# Diccionario de mapeo basado en los resultados de la comparación departamentos
depto_mapping = {'SAN ANDRES ISLAS': 'ARCHIPIELAGO DE SAN ANDRES PROVIDENCIA Y SANTA CATALINA'}

# Reemplazar los nombres incorrectos  el dataframe cocaine_confiscations_MinDefensa_
cocaine_confiscations_MinDefensa_['departamento'] = cocaine_confiscations_MinDefensa_['departamento'].replace(depto_mapping)

# %% [markdown]
#  - Confirmar que discrepancia se solucionó

# %%
# Comparar listas de departamento
compare_lists(cocaine_confiscations_MinDefensa_['departamento'], dept_mpios_codes['dept_name'],
              "Departamentos en cocaine_confiscations_MinDefensa_", "Departamentos dept_mpios_codes")
# Out:
# Departamentos en cocaine_confiscations_MinDefensa_ que no están en Departamentos dept_mpios_codes:
# {'ESPANA', 'SUDAFRICA', 'ITALIA', 'BELGICA', 'VENEZUELA', 'PERU', 'DINAMARCA', 'CURAZAO', 'CROACIA', 'ANTILLAS HOLANDESAS', 'HOLANDA', 'BRASIL', 'FRANCIA', 'MEXICO', 'ALEMANIA', 'PORTUGAL', 'ARUBA', 'INGLATERRA'}

# %%
# Verificar cuantos registros figuran a nombre de 'VENEZUELA', 'PERU', 'BRASIL', 'ESPANA'
confiscation_overseas = cocaine_confiscations_MinDefensa_[cocaine_confiscations_MinDefensa_['departamento'].isin(['ITALIA', 'VENEZUELA', 'DINAMARCA', 'CURAZAO', 'CROACIA', 'ALEMANIA', 'INGLATERRA', 'SUDAFRICA', 'PERU', 'ANTILLAS HOLANDESAS', 'FRANCIA', 'PORTUGAL', 'ARUBA', 'BELGICA', 'HOLANDA', 'MEXICO', 'ESPANA', 'BRASIL'])]
confiscation_overseas['departamento'].value_counts()
# Out:
# departamento
# MEXICO                 79
# BELGICA                53
# ESPANA                 49
# HOLANDA                23
# VENEZUELA              22
# FRANCIA                16
# BRASIL                 15
# INGLATERRA             15
# ARUBA                  14
# PERU                   13
# ITALIA                 13
# CURAZAO                 5
# ALEMANIA                4
# ANTILLAS HOLANDESAS     3
# PORTUGAL                1
# SUDAFRICA               1
# CROACIA                 1
# DINAMARCA               1
# Name: count, dtype: int64

# %%
# Se procede a eliminar esos registros
cocaine_confiscations_MinDefensa_ = cocaine_confiscations_MinDefensa_[~(cocaine_confiscations_MinDefensa_['departamento'].isin(['ITALIA', 'VENEZUELA', 'DINAMARCA', 'CURAZAO', 'CROACIA', 'ALEMANIA', 'INGLATERRA', 'SUDAFRICA', 'PERU', 'ANTILLAS HOLANDESAS', 'FRANCIA', 'PORTUGAL', 'ARUBA', 'BELGICA', 'HOLANDA', 'MEXICO', 'ESPANA', 'BRASIL']))]

# %%
# Comparar nuevamente las listas de departamento
compare_lists(cocaine_confiscations_MinDefensa_['departamento'], dept_mpios_codes['dept_name'],
              "Departamentos en cocaine_confiscations_MinDefensa_", "Departamentos dept_mpios_codes")
# Out:
# Departamentos en cocaine_confiscations_MinDefensa_ que no están en Departamentos dept_mpios_codes:
# set()

# %% [markdown]
# - Verificar que los códigos de municipios que quedaron en el dataset correspondan solamente a códigos reales

# %%
# Comparar listas de códigos
compare_lists(cocaine_confiscations_MinDefensa_['cod_muni'], dept_mpios_codes['dept_mpio_code'],
              "Códigos de municipios en cocaine_confiscations_MinDefensa_", "Códigos de municipios dept_mpios_codes")
# Out:
# Códigos de municipios en cocaine_confiscations_MinDefensa_ que no están en Códigos de municipios dept_mpios_codes:
# set()

# %% [markdown]
# ### Procesamiento final como preparación para integrarlo a la bd de datos del proyecto

# %%
# Eliminar columnas innecesarias
columns_to_drop = ['departamento', 'municipio']
final_cocaine_confiscations_MinDefensa = cocaine_confiscations_MinDefensa_.drop(columns=columns_to_drop)

# %%
# Adicionar columna para trazabilidad de la fuente
final_cocaine_confiscations_MinDefensa['source_id'] = 29

# %%
final_cocaine_confiscations_MinDefensa.columns
# Out:
# Index(['cod_muni', 'fecha_hecho', 'cantidad', 'unidad', 'source_id'], dtype='object')

# %%
# Ajustar nombre de columnas

# Definir el diccionario de traducción
translation_map = {
    'cod_muni': 'dane_code',
    'fecha_hecho': 'year_of_incident',
    'cantidad': 'amount',
    'unidad': 'unit',
    'source_id': 'source_id'
}

# Renombrar las columnas
final_cocaine_confiscations_MinDefensa.rename(columns=translation_map, inplace=True)

# %%
#Estructura final del dataset a integrar a la base de datos
final_cocaine_confiscations_MinDefensa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 194164 entries, 0 to 197073
# Data columns (total 5 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   dane_code         194164 non-null  object
#  1   year_of_incident  194164 non-null  int32
#  2   amount            194164 non-null  float64
#  3   unit              194164 non-null  object
#  4   source_id         194164 non-null  int64
# dtypes: float64(1), int32(1), int64(1), object(2)
# memory usage: 8.1+ MB

# %% [markdown]
# ## Salvar en archivo csv en el drive

# %%
# Guardar en archivos CSV en el drive
final_cocaine_confiscations_MinDefensa.to_csv('/content/drive/MyDrive/analytics_data_proyect/initial_transformation/cocaine_confiscations_MinDefensa.csv', index=False)
