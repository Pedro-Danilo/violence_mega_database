# %% [markdown]
# ###Fuente de la data
#
# Los micro-datos gestionados en este notebook son tomados de www.datos.gov.co y corresponden a datos cuya fuente primaria es el Ministerio de Defensa Nacional de Colombia

# %%
import pandas as pd

# %% [markdown]
# ###Archivo 8rpn-wpty.csv
#
# Contiene información sobre los homicidios y lesiones que reporta la Fuerza Pública (Ejército Nacional, Armada Nacional, Fuerza Aérea y Policía Nacional) en cumplimiento de su deber constitucional o actos de servicio excluyendo vacaciones, permisos y licencias.

# %%
df = pd.read_csv("https://www.datos.gov.co/resource/8rpn-wpty.csv?$limit=500000", dtype={'cod_muni': str})
df.head()
# Out:
#                fecha_hecho  cod_depto     departamento cod_muni  \
# 0  2024-07-29T00:00:00.000         68        SANTANDER    68684
# 1  2024-07-24T00:00:00.000          5        ANTIOQUIA    05576
# 2  2024-07-20T00:00:00.000         76  VALLE DEL CAUCA    76364
# 3  2024-07-19T00:00:00.000         76  VALLE DEL CAUCA    76364
# 4  2024-07-17T00:00:00.000         13          BOLIVAR    13688
#
#              municipio     accion  cantidad
# 0  SAN JOSE DE MIRANDA     HERIDO         1
# 1          PUEBLORRICO  ASESINADO         1
# 2              JAMUNDI     HERIDO         3
# 3              JAMUNDI     HERIDO         1
# 4   SANTA ROSA DEL SUR     HERIDO         1

# %% [markdown]
# ##Revisión y limpieza para integrarlo a la base de datos
#
# ### - Resumen de la estructura del dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20229 entries, 0 to 20228
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   fecha_hecho   20229 non-null  object
#  1   cod_depto     20229 non-null  int64
#  2   departamento  20229 non-null  object
#  3   cod_muni      20229 non-null  object
#  4   municipio     20229 non-null  object
#  5   accion        20229 non-null  object
#  6   cantidad      20229 non-null  int64
# dtypes: int64(2), object(5)
# memory usage: 1.1+ MB

# %% [markdown]
# ### Eliminación de columnas irrelevantes para el proyecto

# %%
relevant_cols = ['cod_muni', 'departamento', 'municipio', 'accion', 'fecha_hecho', 'cantidad']
deaths_in_public_forces_MinDefensa = df[relevant_cols]
deaths_in_public_forces_MinDefensa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20229 entries, 0 to 20228
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cod_muni      20229 non-null  object
#  1   departamento  20229 non-null  object
#  2   municipio     20229 non-null  object
#  3   accion        20229 non-null  object
#  4   fecha_hecho   20229 non-null  object
#  5   cantidad      20229 non-null  int64
# dtypes: int64(1), object(5)
# memory usage: 948.4+ KB

# %% [markdown]
# ### Convertir columna fecha_hecho a tipo date

# %%
# Hacer una copia explícita del DataFrame
deaths_in_public_forces_MinDefensa_ = deaths_in_public_forces_MinDefensa.copy()

# Convertir la columna 'fecha_hecho' a tipo datetime (sin especificar formato)
deaths_in_public_forces_MinDefensa_['fecha_hecho'] = pd.to_datetime(deaths_in_public_forces_MinDefensa_['fecha_hecho'], errors='coerce')

# Extraer solo el año
deaths_in_public_forces_MinDefensa_['fecha_hecho'] = deaths_in_public_forces_MinDefensa_['fecha_hecho'].dt.year

# %% [markdown]
# ### Verificar valores nulos

# %%
deaths_in_public_forces_MinDefensa_.isnull().sum()
# Out:
# cod_muni        0
# departamento    0
# municipio       0
# accion          0
# fecha_hecho     0
# cantidad        0
# dtype: int64

# %% [markdown]
# ### Estandarización de categorizaciones
#
# La estandarización de categorizaciones es el proceso de uniformizar y normalizar los valores de las categorías en un conjunto de datos para asegurar la consistencia y evitar discrepancias. Esto es crucial para la calidad y precisión de los análisis

# %%
# Imprimir categorías únicas para columnas de tipo object
categorical_col = ['departamento', 'municipio', 'accion']
for column in categorical_col:
    print(f"Categorías en la columna '{column}':")
    print(deaths_in_public_forces_MinDefensa_[column].unique())
    print()
# Out:
# Categorías en la columna 'departamento':
# ['SANTANDER' 'ANTIOQUIA' 'VALLE DEL CAUCA' 'BOLIVAR' 'LA GUAJIRA'
#  'BOGOTA D.C.' 'BOYACA' 'META' 'CAUCA' 'CESAR' 'NARIÑO' 'CORDOBA'
#  'MAGDALENA' 'QUINDIO' 'HUILA' 'GUAVIARE' 'NORTE DE SANTANDER' 'ATLANTICO'
#  'CAQUETA' 'ARAUCA' 'PUTUMAYO' 'CALDAS' 'VICHADA' 'AMAZONAS' 'CHOCO'
#  'CASANARE' 'SUCRE' 'RISARALDA' 'TOLIMA' 'CUNDINAMARCA' 'SAN ANDRES ISLAS'
#  'GUAINIA' 'VAUPES']
#
# Categorías en la columna 'municipio':
# ['SAN JOSE DE MIRANDA' 'PUEBLORRICO' 'JAMUNDI' 'SANTA ROSA DEL SUR'
#  'BARRANCAS' 'BOGOTA D.C.' 'SEVILLA' 'SAN PABLO DE BORBUR' 'CURITI'
#  'EL CASTILLO' 'PIENDAMO' 'SUAREZ' 'SANTANDER DE QUILICHAO' 'DIBULLA'
#  'SABANA DE TORRES' 'VALDIVIA' 'VILLAVICENCIO' 'EL CAIRO' 'ARGELIA' 'CALI'
#  'CARTAGENA DE INDIAS' 'VALLEDUPAR' 'SAN PABLO' 'CURUMANI' 'TAMINANGO'
#  'PLANETA RICA' 'BARBACOAS' 'SANTA MARTA' 'BUENAVENTURA' 'YUMBO'
#  'MONTENEGRO' 'NEIVA' 'TULUA' 'PUERTO BERRIO' 'GUATAPE' 'CAPITANEJO'
#  'FRANCISCO PIZARRO' 'PATIA' 'GUADALAJARA DE BUGA' 'MORALES' 'RESTREPO'
#  'CAJIBIO' 'ARENAL' 'MEDELLIN' 'EL RETORNO' 'VISTAHERMOSA' 'MONTECRISTO'
#  'LOS PATIOS' 'SILVIA' 'CALDONO' 'ENTRERRIOS' 'ARMENIA' 'BUCARAMANGA'
#  'MONTERIA' 'BUENOS AIRES' 'GUAPI' 'LOPEZ DE MICAY' 'DONMATIAS'
#  'POLICARPA' 'PUERTO LOPEZ' 'SAN JOSE DEL GUAVIARE' 'BALBOA'
#  'BARRANQUILLA' 'GARZON' 'PIENDAMO - TUNIA' 'AQUITANIA' 'FLORENCIA'
#  'ARAUQUITA' 'SAMANIEGO' 'LA LLANADA' 'SAN VICENTE DEL CAGUAN' 'PITALITO'
#  'TIERRALTA' 'PUERTO CAICEDO' 'LA GLORIA' 'BRICEÑO' 'EL AGUILA' 'CAUCASIA'
#  'TUNJA' 'ANSERMA' 'CARTAGO' 'LA PRIMAVERA' 'ALMAGUER' 'GUACHENE'
#  'ACACIAS' 'SEGOVIA' 'BARRANCABERMEJA' 'OBANDO' 'FLORIDA'
#  'SAN JACINTO DEL CAUCA' 'EL CHARCO' 'PALMIRA' 'RIOHACHA' 'LETICIA'
#  'ALTO BAUDO' 'MAGÜI' 'PINILLOS' 'YOPAL' 'NOVITA' 'EL BANCO'
#  'PUERTO GAITAN' 'LA TEBAIDA' 'LANDAZURI' 'VILLANUEVA' 'TURBO' 'ITUANGO'
#  'LA PINTADA' 'SAN ANDRES DE CUERQUIA' 'SOGAMOSO' 'QUIBDO' 'COCORNA'
#  'AGUACHICA' 'LOS ANDES' 'CUCUTA' 'BOLIVAR' 'LA MACARENA' 'ANORI'
#  'SAN ANDRES DE TUMACO' 'LA CRUZ' 'GAMARRA' 'SANTA FE DE ANTIOQUIA'
#  'EL TAMBO' 'SOLEDAD' 'PUERTO TEJADA' 'CUMBITARA' 'SABANETA' 'PIAMONTE'
#  'NOROSI' 'TAMESIS' 'SANTIAGO DE TOLU' 'CORINTO' 'PUERTO LLERAS' 'DAGUA'
#  'EL ROBLE' 'CANDELARIA' 'GIRALDO' 'TARQUI' 'PIEDECUESTA' 'MUTATA' 'PASTO'
#  'EL TARRA' 'CARMEN DEL DARIEN' 'PUERTO GUZMAN' 'SINCELEJO' 'EL ZULIA'
#  'PEREIRA' 'RIOFRIO' 'TAME' 'AGUAZUL' 'INZA' 'SANTACRUZ' 'BELLO'
#  'EL DONCELLO' 'TIBU' 'BUENAVISTA' 'GIRON' 'PUERTO RICO' 'CONVENCION'
#  'BELEN' 'IBAGUE' 'SOACHA' 'MAPIRIPAN' 'MOCOA' 'PELAYA' 'MORROA' 'CUBARA'
#  'BURITICA' 'HATO COROZAL' 'SAN AGUSTIN' 'TADO' 'YARUMAL' 'DOSQUEBRADAS'
#  'MONIQUIRA' 'PUERTO BOYACA' 'PAILITAS' 'YOTOCO' 'CAJAMARCA'
#  'LA ARGENTINA' 'LA PLATA' 'EL CARMEN' 'SAN JOSE DEL PALMAR' 'MANIZALES'
#  'EL BAGRE' 'BUCARASICA' 'TONA' 'MAICAO' 'CERETE' 'SARAVENA' 'ARBOLEDA'
#  'SARDINATA' 'BETULIA' 'BETANIA' 'RIONEGRO' 'GACHANTIVA' 'IPIALES'
#  'LA PLAYA' 'ABREGO' 'SAN CALIXTO' 'ARJONA' 'ARAUCA' 'SALAZAR' 'RIO IRO'
#  'EL CERRITO' 'ZARAGOZA' 'CALOTO' 'ISTMINA' 'TIMANA' 'TIMBIO' 'ANDALUCIA'
#  'TURBACO' 'CIENAGA DE ORO' 'MAGUI' 'TORIBIO' 'BOGOTA, D.C.' 'CACERES'
#  'SAN EDUARDO' 'PACORA' 'SAN ONOFRE' 'SUSACON' 'LEGUIZAMO' 'CUBARRAL'
#  'CHIMICHAGUA' 'LA MONTAÑITA' 'TINJACA' 'RIOSUCIO' 'PUERTO RONDON'
#  'TERUEL' 'YOLOMBO' 'FLORIDABLANCA' 'ROVIRA' 'CARTAGENA' 'BELALCAZAR'
#  'ROLDANILLO' 'BECERRIL' 'MANAURE' 'LA VICTORIA' 'PUERTO ASIS'
#  'QUEBRADANEGRA' 'OCAÑA' 'BOJAYA' 'POPAYAN' 'SAN MARTIN' 'SALGAR'
#  'SAMPUES' 'CAREPA' 'TEORAMA' 'TUCHIN' 'PLANADAS' 'CAÑASGORDAS' 'NECOCLI'
#  'CHIGORODO' 'ACANDI' 'TARAZA' 'SONSON' 'BAJO BAUDO' 'BARAYA'
#  'PUERTO WILCHES' 'OVEJAS' 'PEQUE' 'URAMITA' 'PUERTO LIBERTADOR'
#  'TIMBIQUI' 'SAN JUAN DE BETULIA' 'SAN MARTIN DE LOBA' 'REGIDOR' 'SIMITI'
#  'CIMITARRA' 'EL CARMEN DE BOLIVAR' 'MAGANGUE' 'SANTAFE DE ANTIOQUIA'
#  'FORTUL' 'GRANADA' 'SAN RAFAEL' 'URRAO' 'VILLAGARZON' 'SANTA ROSA'
#  'PUERTO NARIÑO' 'NEIRA' 'SAN PEDRO' 'QUINCHIA' 'RIO DE ORO' 'PAICOL'
#  'URIBE' 'SAN JACINTO' 'APARTADO' 'LOS CORDOBAS' 'QUIMBAYA' 'ACEVEDO'
#  'USIACURI' 'ACHI' 'HATILLO DE LOBA' 'ANGOSTURA' 'COLOSO' 'FRONTINO'
#  'ITAGUI' 'FILANDIA' 'MIRAFLORES' 'GUADALUPE' 'VILLA DEL ROSARIO'
#  'ABEJORRAL' 'SIACHOQUE' 'LOPEZ' 'CHAPARRAL' 'ENVIGADO' 'SAN ANDRES'
#  'GUAMAL' 'EL ROSARIO' 'LA CUMBRE' 'AMALFI' 'CERRITO' 'GUTIERREZ'
#  'CHIRIGUANA' 'BUGALAGRANDE' 'MESETAS' 'REMEDIOS' 'HACARI' 'LEJANIAS'
#  'LA JAGUA DE IBIRICO' 'LA UNION' 'SATIVANORTE' 'CACOTA'
#  'VALLE DEL GUAMUEZ' 'BAHIA SOLANO' 'GIRARDOT' 'PAZ DE ARIPORO'
#  'SAN JOSE DE URE' 'CHINCHINA' 'INIRIDA' 'MANZANARES'
#  'EL LITORAL DEL SAN JUAN' 'TRINIDAD' 'SABANAS DE SAN ANGEL'
#  'MEDIO SAN JUAN' 'CHACHAGUI' 'CALAMAR' 'VERSALLES' 'ALBANIA' 'GIRARDOTA'
#  'TOLEDO' 'ROBERTO PAYAN' 'CHINACOTA' 'RIO VIEJO' 'GUACARI' 'BOSCONIA'
#  'SALENTO' 'FACATATIVA' 'MADRID' 'CALDAS' 'MALAMBO' 'RICAURTE' 'BARBOSA'
#  'JAMBALO' 'GONZALEZ' 'PROVIDENCIA' 'ZONA BANANERA' 'MOSQUERA'
#  'SABANAGRANDE' 'LA CALERA' 'LEBRIJA' 'PAJARITO' 'CARTAGENA DEL CHAIRA'
#  'CONDOTO' 'SANDONA' 'MATANZA' 'BARANOA' 'CALARCA' 'VELEZ' 'LIBORINA'
#  'YONDO' 'URIBIA' 'SAHAGUN' 'CUMBAL' 'GUARANDA' 'HOBO'
#  'SAN LUIS DE PALENQUE' 'SAN ANDRES SOTAVENTO' 'FUSAGASUGA' 'CAJICA'
#  'FOMEQUE' 'OLAYA HERRERA' 'SAN JOSE' 'LORICA' 'MONTELIBANO' 'TELLO'
#  'PRADERA' 'SOLITA' 'DUITAMA' 'CAICEDONIA' 'VIJES' 'SAN CARLOS'
#  'LA DORADA' 'ISNOS' 'ILES' 'COTA' 'PALESTINA' 'DABEIBA' 'MIRANDA'
#  'CRAVO NORTE' 'CAMPOALEGRE' 'PAUNA' 'SABANALARGA' 'CIENAGA' 'GUATAQUI'
#  'CHOCONTA' 'LA APARTADA' 'LA VEGA' 'SOLANO' 'CUMARIBO' 'MANI' 'AIPE'
#  'ZAPATOCA' 'PUERTO CARREÑO' 'SAN LUIS' 'TIBASOSA' 'UNGUIA'
#  'SANTA ROSA DE CABAL' 'VILLAGOMEZ' 'SANTIAGO' 'SAN VICENTE DE CHUCURI'
#  'GRAMALOTE' 'YALI' 'FILADELFIA' 'ANDES' 'ARANZAZU' 'EL COLEGIO' 'ZARZAL'
#  'ANZA' 'LA ESTRELLA' 'MURINDO' 'LA TOLA' 'VENECIA' 'AGUSTIN CODAZZI'
#  'GALAPA' 'AGRADO' 'NARIÑO' 'CHOACHI' 'QUETAME' 'TESALIA' 'TUBARA'
#  'HELICONIA' 'SIBATE' 'PAIPA' 'TAMARA' 'ALGECIRAS' 'DON MATIAS'
#  'VALPARAISO' 'TIQUISIO' 'EL PASO' 'COELLO' 'POLONUEVO' 'ALTAMIRA'
#  'GUACHUCAL' 'TORO' 'PORE' 'ALBAN' 'SAN JUAN DEL CESAR' 'SUAZA'
#  'ZIPAQUIRA' 'PUERTO ESCONDIDO' 'PANQUEBA' 'CERTEGUI' 'LA CELIA'
#  'AMBALEMA' 'PITAL' 'EL PAUJIL' 'GACHANCIPA' 'CUMARAL' 'VILLA DE LEYVA'
#  'HATONUEVO' 'JURADO' 'GIGANTE' 'SOPETRAN' 'CHIPAQUE' 'SAN DIEGO'
#  'COLOMBIA' 'TIBACUY' 'CISNEROS' 'SAN FRANCISCO' 'LOS SANTOS'
#  'EL SANTUARIO' 'JARDIN' 'SAN ALBERTO' 'RETIRO' 'SALADOBLANCO' 'MANATI'
#  'CIRCASIA' 'CHIQUINQUIRA' 'LA FLORIDA' 'SAN GIL' 'AMAGA' 'CAICEDO'
#  'SOCORRO' 'TOCAIMA' 'PADILLA' 'MAJAGUAL' 'PUEBLO BELLO' 'PONEDERA'
#  'PAMPLONA' 'AGUADAS' 'LABRANZAGRANDE' 'PUERTO COLOMBIA' 'CHITARAQUE'
#  'SOCHA' 'SAN SEBASTIAN DE BUENAVISTA' 'COROZAL' 'COTORRA' 'SACHICA'
#  'BAGADO' 'VILLAVIEJA' 'YACUANQUER' 'ELIAS' 'CASTILLA LA NUEVA'
#  'SAN MARCOS' 'SANTA BARBARA' 'SAN BENITO ABAD' 'SANTA ROSA DE OSOS'
#  'SAN PEDRO DE URABA' 'MERCADERES' 'MITU' 'MARIQUITA'
#  'EL CARMEN DE VIBORAL' 'GOMEZ PLATA' 'SITIONUEVO' 'CALIMA' 'FLANDES'
#  'CHINU' 'EL TABLON DE GOMEZ' 'CHINAVITA' 'COMBITA' 'PUERTO CONCORDIA'
#  'CANALETE' 'APULO' 'SAN BERNARDO' 'TOPAGA' 'GUAPOTA' 'MONTERREY' 'IZA'
#  'SOPO' 'SAN LORENZO' 'PIEDRAS' 'PASCA' 'CABRERA' 'LA PAZ' 'TRUJILLO'
#  'PURACE' 'VITERBO' 'VALENCIA' 'NATAGA' 'TANGUA' 'TOCA'
#  'UNION PANAMERICANA' 'PUERTO TRIUNFO' 'PIVIJAY' 'YAGUARA' 'VILLA RICA'
#  'FUNZA' 'LA CEJA' 'TITIRIBI' 'ESPINAL' 'SAN ROQUE' 'LURUACO'
#  'PARATEBUENO' 'SAN JOSE DEL FRAGUA' 'CAMPAMENTO' 'MEDINA' 'MARINILLA'
#  'SUAN' 'MOÑITOS' 'MILAN' 'GUARNE' 'PIJAO' 'SIPI' 'NUQUI' 'REPELON'
#  'SAN JOSE DE LA MONTAÑA' 'TOTORO' 'EBEJICO' 'LA VIRGINIA' 'SUPIA'
#  'SANTA ISABEL' 'RONDON' 'SUBACHOQUE' 'MARIPI' 'GINEBRA' 'LIBANO'
#  'SAN JERONIMO' 'CHISCAS' 'BOCHALEMA' 'MACEO' 'SAN VICENTE' 'MALLAMA'
#  'EL DOVIO' 'COPACABANA' 'SOCOTA' 'CERINZA' 'AYAPEL' 'PALERMO' 'ALCALA'
#  'PUERTO NARE' 'LA ESPERANZA' 'RIOBLANCO' 'FREDONIA' 'TOCANCIPA' 'SUESCA'
#  'SAN MIGUEL' 'MARIA LA BAJA' 'CAMPO DE LA CRUZ' 'ULLOA' 'OPORAPA'
#  'GUAITARILLA' 'SABOYA' 'VILLAHERMOSA' 'SANTA MARIA' 'RIO QUITO'
#  'SANTO TOMAS' 'JERICO' 'CONTADERO' 'EL COCUY' 'ALEJANDRIA'
#  'PUERTO SALGAR' 'CORDOBA' 'TARSO' 'PURIFICACION' 'CONCORDIA' 'FUNES'
#  'SIBUNDOY' 'TUQUERRES' 'COLON' 'PALMAS DEL SOCORRO' 'ZAMBRANO'
#  'SAN JUAN DE ARAMA' 'PARAMO' 'SAN JUAN NEPOMUCENO' 'PEÑOL'
#  'SANTO DOMINGO' 'FONSECA' 'GUICAN' 'MACARAVITA' 'RIVERA' 'QUIPAMA'
#  'CAROLINA' 'LA MESA' 'PULI' 'TAURAMENA' 'DISTRACCION' 'CAMPOHERMOSO'
#  'SUCRE' 'LA JAGUA DEL PILAR' 'NEMOCON' 'NATAGAIMA' 'CIUDAD BOLIVAR'
#  'OICATA' 'LOS PALMITOS' 'UBALA' 'VILLAMARIA' 'COROMORO' 'VEGACHI'
#  'BUESACO' 'GAMEZA' 'EL PLAYON' 'CHARALA' 'TOLU VIEJO' 'CACHIPAY' 'OIBA'
#  'ORITO' 'SAMACA' 'OLAYA' 'CHIMA' 'CONCEPCION' 'SANTUARIO' 'SAN BENITO'
#  'CARAMANTA' 'LEIVA' 'VILLA CARO' 'BELEN DE LOS ANDAQUIES' 'SUTAMARCHAN'
#  'JESUS MARIA' 'URUMITA' 'SAN JUAN DE RIO SECO' 'PAEZ' 'VALLE DE SAN JOSE'
#  'SILVANIA' 'TASCO' 'MEDIO ATRATO' 'MALAGA' 'CALIFORNIA' 'SUAITA' 'HATO'
#  'DOLORES' 'ARIGUANI' 'SURATA' 'ANOLAIMA' 'SAN PEDRO DE CARTAGO' 'CHIVOR'
#  'ATACO' 'TENA' 'TURBANA' 'SAN LUIS DE SINCE' 'PUERTO SANTANDER' 'IQUIRA'
#  'SAMANA' 'EL CANTON DEL SAN PABLO' 'ORTEGA' 'SAN ANTONIO' 'CHITAGA'
#  'HONDA' 'VENTAQUEMADA' 'ATRATO' 'MELGAR' 'LINARES' 'LLORO' 'LA CHORRERA'
#  'TENJO' 'RAMIRIQUI' 'PINCHOTE' 'SAPUYES' 'CHIBOLO' 'HISPANIA' 'LA SALINA'
#  'EL COPEY' 'EL ESPINO' 'SAN CAYETANO' 'NOBSA' 'LA BELLEZA' 'ANGELOPOLIS'
#  'OROCUE' 'SACAMA' 'CONFINES' 'CHIA' 'MOTAVITA' 'FUNDACION' 'PUEBLOVIEJO'
#  'MISTRATO' 'EL ROSAL' 'EL CARMEN DE ATRATO' 'OCAMONTE' 'CHITA' 'CARURU'
#  'GUEPSA' 'SANTA CATALINA' 'VILLA DE SAN DIEGO DE UBATE' 'ARCABUCO'
#  'TABIO' 'VILLAPINZON' 'RONCESVALLES' 'ANAPOIMA' 'LENGUAZAQUE' 'SORACA'
#  'MARMATO' 'MOMIL' 'ANCUYA' 'PALMAR DE VARELA' 'CANTAGALLO'
#  'BARRANCO MINAS' 'CUNDAY' 'CURILLO' 'COVEÑAS' 'SAN JOAQUIN' 'PLATO'
#  'EL CARMEN DE CHUCURI' 'GUADUAS' 'SAN LUIS DE GACENO' 'PUEBLO RICO'
#  'TENZA' 'SOTAQUIRA' 'SALDAÑA' 'ARMERO' 'TIBANA' 'MONGUA' 'PISBA'
#  'EL DORADO' 'PUENTE NACIONAL' 'SANTA ROSA DE VITERBO' 'SAN JUANITO'
#  'NUNCHIA' 'RECETOR' 'CORRALES' 'VILLETA' 'PUERRES' 'VETAS' 'ANSERMANUEVO'
#  'MOGOTES' 'CAIMITO' 'SAN ANTONIO DEL TEQUENDAMA' 'GUAYABETAL' 'GACHETA'
#  'BARRANCA DE UPIA' 'PAZ DE RIO' 'PESCA' 'MEDIO BAUDO' 'ZETAQUIRA'
#  'LA PEÑA' 'JUAN DE ACOSTA' 'ROSAS' 'MAHATES' 'PALMAR' 'AGUA DE DIOS'
#  'MUZO' 'COGUA' 'GAMA' 'CONTRATACION' 'PENSILVANIA' 'SOPLAVIENTO'
#  'LA MERCED' 'SAN ANTERO' 'CABUYARO' 'VILLARRICA' 'TOTA' 'EL PEÑON' 'APIA'
#  'SAN CARLOS DE GUAROA' 'PUERTO ALEGRIA' 'UMBITA' 'SAN MATEO' 'SANTANA'
#  'GUAMO' 'VIGIA DEL FUERTE' 'VENADILLO' 'COYAIMA' 'SALAMINA' 'GENOVA'
#  'FRESNO' 'NECHI' 'SAN JUAN DE URABA' 'VICTORIA' 'TUTA' 'TUTAZA']
#
# Categorías en la columna 'accion':
# ['HERIDO' 'ASESINADO']

# %% [markdown]
# - Borrar espacios en blanco al principio y al final, cambiar a mayúsculas, remover acentos y eliminar signos extraños

# %%
import unicodedata

def remove_accents_and_special_chars(input_str):
    # Normalizar la cadena a NFKD
    nfkd_form = unicodedata.normalize('NFKD', input_str)

    # Eliminar acentos
    no_accents = ''.join([c for c in nfkd_form if not unicodedata.combining(c)])

    # Definir caracteres no deseados
    unwanted_chars = [',', ';', '!', '?', '#', '$', '%']

    # Eliminar caracteres no deseados
    cleaned_str = ''.join([c for c in no_accents if c not in unwanted_chars])

    # Remover espacios en blanco al principio y al final, y convertir a mayúsculas
    result = cleaned_str.strip().upper()

    return result

# %%
# Aplicar la función a todas las columnas categóricas
for col in categorical_col:
    deaths_in_public_forces_MinDefensa_[col] = deaths_in_public_forces_MinDefensa_[col].apply(remove_accents_and_special_chars)

# %% [markdown]
# - Codificación de algunas variables categóricas

# %% [markdown]
# ### Verificar que los valores en "cod_muni" coincidan con los códigos reales de municipios
#
# Los códigos reales de los municipios de Colombia, están almacenados en la base de datos PostgreSQL del proyecto, en la tabla municipalities dentro del campo dept_mpio_code, junto con la informacion necesaria para georeferenciar todos los municipios y departamentos de Colombia. Este campo guarda el código del municipio en un formato string de exactamente 5 caracteres.
#
# Para hacer esta verificación, previamente exportamos desde la base de datos PostgreSQL un DataFrame con los siguientes campos: dept_name, mpio_name y dept_mpio_code, los cuales contienen la información de los departamentos y municipios oficiales, junto con sus respectivos códigos. Este DataFrame se carga en la siguiente celda y se utiliza para comparar con la columna "codigo_mpio"

# %%
dept_mpios_codes = pd.read_csv("/content/drive/MyDrive/analytics_data_proyect/deptos_mupios.csv", index_col=0, dtype={'dept_mpio_code': str})
print(dept_mpios_codes.info())
dept_mpios_codes.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1121 entries, 0 to 1120
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   dept_mpio_code  1121 non-null   object
#  1   dept_name       1121 non-null   object
#  2   mupio_name      1121 non-null   object
# dtypes: object(3)
# memory usage: 35.0+ KB
# None
#   dept_mpio_code dept_name mupio_name
# 0          97001    VAUPES       MITU
# 1          97161    VAUPES     CARURU
# 2          97511    VAUPES      PACOA
# 3          97666    VAUPES    TARAIRA
# 4          97777    VAUPES  PAPUNAHUA

# %% [markdown]
#  -  Verificar la consistencia de la columna "cod_muni" en el df deaths_in_public_forces_MinDefensa_

# %%
# Asegurarnos de que todos los valores en 'codigo_m' sean strings
deaths_in_public_forces_MinDefensa_['cod_muni'] = deaths_in_public_forces_MinDefensa_['cod_muni'].astype(str)

# Calcular la longitud de cada valor en la columna
longitudes = deaths_in_public_forces_MinDefensa_['cod_muni'].apply(len)

# Verificar si todas las longitudes son iguales
longitudes.nunique() == 1
# Out:
# True

# %%
# Mostrar longitudes únicas (opcional)
print(f"Longitudes únicas: {longitudes.unique()}")
# Out:
# Longitudes únicas: [5]

# %%
# Contar registros por longitud
long_df = longitudes.value_counts().reset_index()
long_df.rename(columns={'codigo_dane': 'no_dígitos_codigo_dane'}, inplace=True)
long_df['percentage'] = (long_df['count'] / len(longitudes))
long_df.head()
# Out:
#    cod_muni  count  percentage
# 0         5  20229         1.0

# %%
# Mostrar una muestra de registros para cada longitud
for longitud in longitudes.value_counts().index:
    print(f"Muestra de registros con longitud {longitud}:")
    muestra = deaths_in_public_forces_MinDefensa_[longitudes == longitud].head(5)  # Muestra de los primeros 5 registros
    print(muestra[['cod_muni']])
    print()
# Out:
# Muestra de registros con longitud 5:
#   cod_muni
# 0    68684
# 1    05576
# 2    76364
# 3    76364
# 4    13688

# %% [markdown]
# Nota: el 100%  de los codigos que identifican a los municipios en el df deaths_in_public_forces_MinDefensa corresponden a string de 5 caracteres, igual a los almacenados en la base de datos del proyecto

# %% [markdown]
# - Comparar que los nombres de los departamentos en cada dataframe esten escritos correctamente
#
# Se aplica la función para racionalizar columnas categoricas (Borrar espacios en blanco al principio y al final, cambiar a mayúsculas, remover acentos y eliminar signos extraños) al df 'dept_mpiios_codes'

# %%
# Aplicar función a columnas 'dept_name', 'mupio_name'
for col in dept_mpios_codes[['dept_name', 'mupio_name']]:
    dept_mpios_codes[col] = dept_mpios_codes[col].apply(remove_accents_and_special_chars)

# %%
# Función para comparar listas y mostrar diferencias
def compare_lists(df1_col, df2_col, label1, label2):
    # Extraer listas únicas y normalizar
    list1 = set(df1_col.str.strip().str.upper().unique())
    list2 = set(df2_col.str.strip().str.upper().unique())

    # Encontrar diferencias
    only_in_list1 = list1 - list2
    only_in_list2 = list2 - list1

    # Imprimir resultados
    print(f"{label1} que no están en {label2}:")
    print(only_in_list1)
    # print(f"{label2} que no están en {label1}:")
    # print(only_in_list2)
    # print()

# %% [markdown]
#   - Comparar nombres de departamentos en los dataframes

# %%
# Comparar listas de departamento
compare_lists(deaths_in_public_forces_MinDefensa_['departamento'], dept_mpios_codes['dept_name'],
              "Departamentos en deaths_in_public_forces_MinDefensa_", "Departamentos dept_mpios_codes")
# Out:
# Departamentos en deaths_in_public_forces_MinDefensa_ que no están en Departamentos dept_mpios_codes:
# {'SAN ANDRES ISLAS'}

# %% [markdown]
#   - Solucionar discrepancias en nombres de departamento

# %%
# Diccionario de mapeo basado en los resultados de la comparación departamentos
depto_mapping = {'SAN ANDRES ISLAS': 'ARCHIPIELAGO DE SAN ANDRES PROVIDENCIA Y SANTA CATALINA'}

# Reemplazar los nombres incorrectos  el dataframe deaths_in_public_forces_MinDefensa_
deaths_in_public_forces_MinDefensa_['departamento'] = deaths_in_public_forces_MinDefensa_['departamento'].replace(depto_mapping)

# %% [markdown]
#  - Confirmar que discrepancia se solucionó

# %%
# Comparar listas de departamento
compare_lists(deaths_in_public_forces_MinDefensa_['departamento'], dept_mpios_codes['dept_name'],
              "Departamentos en deaths_in_public_forces_MinDefensa_", "Departamentos dept_mpios_codes")
# Out:
# Departamentos en deaths_in_public_forces_MinDefensa_ que no están en Departamentos dept_mpios_codes:
# set()

# %% [markdown]
# - Verificar que los códigos de municipios que quedaron en el dataset correspondan solamente a códigos reales

# %%
# Comparar listas de códigos
compare_lists(deaths_in_public_forces_MinDefensa_['cod_muni'], dept_mpios_codes['dept_mpio_code'],
              "Códigos de municipios en deaths_in_public_forces_MinDefensa_", "Códigos de municipios dept_mpios_codes")
# Out:
# Códigos de municipios en deaths_in_public_forces_MinDefensa_ que no están en Códigos de municipios dept_mpios_codes:
# set()

# %% [markdown]
# ### Procesamiento final como preparación para integrarlo a la bd de datos del proyecto

# %%
# Eliminar columnas innecesarias
columns_to_drop = ['departamento', 'municipio']
final_deaths_in_public_forces_MinDefensa = deaths_in_public_forces_MinDefensa_.drop(columns=columns_to_drop)

# %%
# Adicionar columna para trazabilidad de la fuente
final_deaths_in_public_forces_MinDefensa['source_id'] = 19

# %%
final_deaths_in_public_forces_MinDefensa.columns
# Out:
# Index(['cod_muni', 'accion', 'fecha_hecho', 'cantidad', 'source_id'], dtype='object')

# %%
# Ajustar nombre de columnas

# Definir el diccionario de traducción
translation_map = {
    'cod_muni': 'dane_code',
    'fecha_hecho': 'year_of_incident',
    'accion': 'action',
    'cantidad': 'amount',
    'source_id': 'source_id'
}

# Renombrar las columnas
final_deaths_in_public_forces_MinDefensa.rename(columns=translation_map, inplace=True)

# %%
#Estructura final del dataset a integrar a la base de datos
final_deaths_in_public_forces_MinDefensa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20229 entries, 0 to 20228
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   dane_code         20229 non-null  object
#  1   action            20229 non-null  object
#  2   year_of_incident  20229 non-null  int32
#  3   amount            20229 non-null  int64
#  4   source_id         20229 non-null  int64
# dtypes: int32(1), int64(2), object(2)
# memory usage: 711.3+ KB

# %% [markdown]
# ## Salvar en archivo csv en el drive

# %%
# Guardar en archivos CSV en el drive
final_deaths_in_public_forces_MinDefensa.to_csv('/content/drive/MyDrive/analytics_data_proyect/initial_transformation/deaths_in_public_forces_MinDefensa.csv', index=False)
