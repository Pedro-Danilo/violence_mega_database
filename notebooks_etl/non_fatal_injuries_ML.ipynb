# %% [markdown]
# ###Fuente de la data
#
# Los micro-datos gestionados en este notebook son tomados de www.datos.gov.co y corresponden a datos cuya fuente primaria es el Instituto Nacional de Medicina Legal y Ciencias Forenses

# %%
import pandas as pd

# %% [markdown]
# ###Archivo 79dd-d24f.csv
#
# Contiene información sobre las lesiones no fatales de causa externa ocurridas en el territorio nacional Colombiano en el periodo de tiempo comprendido entre el 01 de enero de 2023 al 31 de julio 2024, de los cuales tiene conocimiento y son registrados por el Instituto Nacional de Medicina Legal y Ciencias Forenses.

# %%
df = pd.read_csv("https://www.datos.gov.co/resource/79dd-d24f.csv?$limit=500000")
df.head(2)
# Out:
#    id  a_o_del_hecho sexo_de_la_victima grupo_de_edad_de_la_victima  \
# 0   1           2023             Hombre                   (25 a 29)
# 1   2           2023              Mujer                   (05 a 09)
#
#   mes_del_hecho dia_del_hecho departamento_del_hecho_dane  \
# 0     diciembre       domingo                      Nariño
# 1     noviembre        martes                   Antioquia
#
#   municipio_del_hecho_dane                           lesion_no_fatal_de_causa  \
# 0                 El Peñol                 Lesiones por eventos de transporte
# 1                Caramanta  Exámenes medico legales por pesunto delito sexual
#
#                                               estado
# 0  Datos preliminares sujetos a cambios por actua...
# 1  Datos preliminares sujetos a cambios por actua...

# %% [markdown]
# ###Archivo v9ng-hhuy.csv
#
# Contiene información sobre las lesiones no fatales de causa externa ocurridas en el territorio nacional Colombiano en el periodo de tiempo comprendido entre el 01 de enero de 2020 y 31 de diciembre de 2022, de los cuales tiene conocimiento y son registrados por el Instituto Nacional de Medicina Legal y Ciencias Forenses.

# %%
df1 = pd.read_csv("https://www.datos.gov.co/resource/v9ng-hhuy.csv?$limit=600000")
df1.head(2)
# Out:
#    id  a_o_del_hecho sexo_de_la_victima grupo_de_edad_de_la_victima  \
# 0   1           2021              Mujer                   (60 a 64)
# 1   2           2021              Mujer                   (30 a 34)
#
#   mes_del_hecho dia_del_hecho departamento_del_hecho_dane  \
# 0         julio        martes                Cundinamarca
# 1         julio       domingo                Cundinamarca
#
#   municipio_del_hecho_dane lesion_no_fatal_de_causa             estado
# 0                    Manta  Violencia interpersonal  Datos definitivos
# 1                    Manta      Violencia de pareja  Datos definitivos

# %% [markdown]
# ###Archivo 6cjn-eevd.csv
#
# Contiene información sobre las lesiones accidentales ocurridas en el territorio nacional Colombiano en el periodo de tiempo comprendido entre los años 2016 y 2019, de los cuales tiene conocimiento y son registrados por el Instituto Nacional de Medicina Legal y Ciencias Forenses.

# %%
df2 = pd.read_csv("https://www.datos.gov.co/resource/6cjn-eevd.csv?$limit=600000")
df2.head(2)
# Out:
#    id  a_o_del_hecho sexo_de_la_victima grupo_de_edad_de_la_victima  \
# 0   1           2016              Mujer                   (70 a 74)
# 1   2           2016              Mujer                   (35 a 39)
#
#   mes_del_hecho dia_del_hecho departamento_del_hecho_dane  \
# 0       febrero        martes                       Huila
# 1          mayo       domingo                Bogotá, D.C.
#
#   municipio_del_hecho_dane lesion_no_fatal_de_causa             estado
# 0                    Neiva    Lesiones accidentales  Datos definitivos
# 1             Bogotá, D.C.    Lesiones accidentales  Datos definitivos

# %% [markdown]
# ###Archivo agad-646z.csv
#
# Contiene información sobre los casos de violencia de pareja ocurridos en el territorio nacional Colombiano en el periodo de tiempo comprendido entre los años 2016 y 2019, de los cuales tiene conocimiento y son registrados por el Instituto Nacional de Medicina Legal y Ciencias Forenses.

# %%
df3 = pd.read_csv("https://www.datos.gov.co/resource/agad-646z.csv?$limit=500000")
df3.head(2)
# Out:
#    id  a_o_del_hecho sexo_de_la_victima grupo_de_edad_de_la_victima  \
# 0   1           2016             Hombre                   (30 a 34)
# 1   2           2016             Hombre                   (35 a 39)
#
#   mes_del_hecho dia_del_hecho departamento_del_hecho_dane  \
# 0       octubre     miércoles                   Santander
# 1         abril        sábado                    Casanare
#
#   municipio_del_hecho_dane lesion_no_fatal_de_causa             estado
# 0          Barrancabermeja      Violencia de pareja  Datos definitivos
# 1                    Yopal      Violencia de pareja  Datos definitivos

# %% [markdown]
# ###Archivo ers2-kerr.csv
#
# Contiene información sobre los casos de violencia intrafamiliar ocurridos en el territorio nacional Colombiano en el periodo de tiempo comprendido entre los años 2016 y 2019, de los cuales tiene conocimiento y son registrados por el Instituto Nacional de Medicina Legal y Ciencias Forenses.

# %%
df4 = pd.read_csv("https://www.datos.gov.co/resource/ers2-kerr.csv?$limit=500000")
df4.head(2)
# Out:
#    id  a_o_del_hecho sexo_de_la_victima grupo_de_edad_de_la_victima  \
# 0   1           2016             Hombre                   (00 a 04)
# 1   2           2016             Hombre                   (00 a 04)
#
#   mes_del_hecho dia_del_hecho departamento_del_hecho_dane  \
# 0       octubre       viernes                Bogotá, D.C.
# 1         marzo       domingo             Valle del Cauca
#
#   municipio_del_hecho_dane                           lesion_no_fatal_de_causa  \
# 0             Bogotá, D.C.  Violencia contra niños, niñas y adolescentes (...
# 1      Guadalajara de Buga  Violencia contra niños, niñas y adolescentes (...
#
#               estado
# 0  Datos definitivos
# 1  Datos definitivos

# %% [markdown]
# ###Archivo e3xi-4zq5.csv
#
# Contiene información sobre los casos de violencia interpersonal ocurridos en el territorio nacional Colombiano en el periodo de tiempo comprendido entre los años 2016 y 2019, de los cuales tiene conocimiento y son registrados por el Instituto Nacional de Medicina Legal y Ciencias Forenses.

# %%
df5 = pd.read_csv("https://www.datos.gov.co/resource/e3xi-4zq5.csv?$limit=500000")
df5.head(2)
# Out:
#    id  a_o_del_hecho sexo_de_la_victima grupo_de_edad_de_la_victima  \
# 0   1           2016             Hombre                   (45 a 49)
# 1   2           2016             Hombre                   (20 a 24)
#
#   mes_del_hecho dia_del_hecho departamento_del_hecho_dane  \
# 0        agosto         lunes                   Atlántico
# 1       febrero       domingo                   Atlántico
#
#   municipio_del_hecho_dane lesion_no_fatal_de_causa             estado
# 0             Barranquilla  Violencia interpersonal  Datos definitivos
# 1                  Soledad  Violencia interpersonal  Datos definitivos

# %% [markdown]
# ###Archivo hyqu-diue.csv
#
# Contiene información sobre los exámenes médico legales por presunto delito sexual practicados, y cuyos hechos ocurrieron en Colombia en el periodo de tiempo comprendido entre los años 2016 y 2019, de los cuales tiene conocimiento y son registrados por el Instituto Nacional de Medicina Legal y Ciencias Forenses.

# %%
df6 = pd.read_csv("https://www.datos.gov.co/resource/hyqu-diue.csv?$limit=500000")
df6.head(2)
# Out:
#    id  a_o_del_hecho sexo_de_la_victima grupo_de_edad_de_la_victima  \
# 0   1           2016             Hombre                   (00 a 04)
# 1   2           2016             Hombre                   (05 a 09)
#
#   mes_del_hecho dia_del_hecho departamento_del_hecho_dane  \
# 0        agosto        jueves                      Caldas
# 1         junio       domingo          Norte de Santander
#
#   municipio_del_hecho_dane                           lesion_no_fatal_de_causa  \
# 0                Manizales  Exámenes medico legales por pesunto delito sexual
# 1                   Cúcuta  Exámenes medico legales por pesunto delito sexual
#
#               estado
# 0  Datos definitivos
# 1  Datos definitivos

# %% [markdown]
# ###Archivo ezhf-hscf.csv
#
# Contiene información sobre las lesiones por accidentes de transporte ocurridas en el territorio nacional Colombiano en el periodo de tiempo comprendido entre los años 2016 y 2019, de los cuales tiene conocimiento y son registrados por el Instituto Nacional de Medicina Legal y Ciencias Forenses.

# %%
df7 = pd.read_csv("https://www.datos.gov.co/resource/ezhf-hscf.csv?$limit=500000")
df7.head(2)
# Out:
#    id  a_o_del_hecho sexo_de_la_victima grupo_de_edad_de_la_victima  \
# 0   1           2016             Hombre                   (40 a 44)
# 1   2           2016             Hombre                   (35 a 39)
#
#   mes_del_hecho dia_del_hecho departamento_del_hecho_dane  \
# 0        Agosto       Viernes                Bogotá, D.C.
# 1        Agosto        Martes             Valle del Cauca
#
#   municipio_del_hecho_dane              lesion_no_fatal_de_causa  \
# 0             Bogotá, D.C.  Lesiones en accidentes de transporte
# 1                     Cali  Lesiones en accidentes de transporte
#
#               estado
# 0  Datos definitivos
# 1  Datos definitivos

# %% [markdown]
# ##Revisión y limpieza para integrarlo a la base de datos
#
# ### - Unir en forma vertical los 8 dataset en uno solo

# %%
# Lista de los DataFrames a unir
dataframes = [(df, 'df'), (df1, 'df1'), (df2, 'df2'), (df3, 'df3'), (df4, 'df4'), (df5, 'df5'), (df6, 'df6'), (df7, 'df7')]

# %%
# Verificar que tienen los mismos nombres de columnas

# Función que compara los nombres de las columnas de dos df
def compare_columns(df1, df2):
    if df1.columns.equals(df2.columns):
        return True
    else:
        return False

# Seleccionar el primer DataFrame como referencia
df_reference = dataframes[0][0]

# Comparar cada DataFrame con el de referencia
for d, name in dataframes[1:]:
    if compare_columns(df_reference, d):
      print(f"Los DataFrames {dataframes[0][1]} y {name} tienen las mismas columnas.")
# Out:
# Los DataFrames df y df1 tienen las mismas columnas.
# Los DataFrames df y df2 tienen las mismas columnas.
# Los DataFrames df y df3 tienen las mismas columnas.
# Los DataFrames df y df4 tienen las mismas columnas.
# Los DataFrames df y df5 tienen las mismas columnas.
# Los DataFrames df y df6 tienen las mismas columnas.
# Los DataFrames df y df7 tienen las mismas columnas.

# %%
# Comparar los tipos de datos de las columnas correspondientes
for col in df_reference.columns:
    for d, name in dataframes[1:]:
        if d[col].dtype != df_reference[col].dtype:
            print(f"La columna '{col}' tiene diferentes tipos de datos en los DataFrames.")

# %%
# Unir los DataFrames verticalmente
dfs = [d for d, _ in dataframes]
non_fatal_injuries_ML = pd.concat(dfs, axis = 0, ignore_index=True)
non_fatal_injuries_ML.head()
# Out:
#    id  a_o_del_hecho sexo_de_la_victima grupo_de_edad_de_la_victima  \
# 0   1           2023             Hombre                   (25 a 29)
# 1   2           2023              Mujer                   (05 a 09)
# 2   3           2023              Mujer                   (20 a 24)
# 3   4           2023              Mujer                   (55 a 59)
# 4   5           2023              Mujer                   (25 a 29)
#
#   mes_del_hecho dia_del_hecho departamento_del_hecho_dane  \
# 0     diciembre       domingo                      Nariño
# 1     noviembre        martes                   Antioquia
# 2     noviembre         lunes                      Caldas
# 3         marzo        sábado                       Cauca
# 4         junio       domingo                       Cauca
#
#   municipio_del_hecho_dane                           lesion_no_fatal_de_causa  \
# 0                 El Peñol                 Lesiones por eventos de transporte
# ...

# %%
len(df) + len(df1) + len(df2) + len(df3) + len(df4) + len(df5) + len(df6) + len(df7) == len(non_fatal_injuries_ML)
# Out:
# True

# %% [markdown]
# ### - Resumen de la estructura del dataset resultante

# %%
non_fatal_injuries_ML.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1891583 entries, 0 to 1891582
# Data columns (total 10 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   id                           int64
#  1   a_o_del_hecho                int64
#  2   sexo_de_la_victima           object
#  3   grupo_de_edad_de_la_victima  object
#  4   mes_del_hecho                object
#  5   dia_del_hecho                object
#  6   departamento_del_hecho_dane  object
#  7   municipio_del_hecho_dane     object
#  8   lesion_no_fatal_de_causa     object
#  9   estado                       object
# dtypes: int64(2), object(8)
# memory usage: 144.3+ MB

# %% [markdown]
# ### Eliminación de columnas irrelevantes para el proyecto

# %%
relevant_cols = ['a_o_del_hecho', 'sexo_de_la_victima', 'grupo_de_edad_de_la_victima', 'departamento_del_hecho_dane', 'municipio_del_hecho_dane', 'lesion_no_fatal_de_causa']
non_fatal_injuries_ML_ = non_fatal_injuries_ML[relevant_cols]
non_fatal_injuries_ML_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1891583 entries, 0 to 1891582
# Data columns (total 6 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   a_o_del_hecho                int64
#  1   sexo_de_la_victima           object
#  2   grupo_de_edad_de_la_victima  object
#  3   departamento_del_hecho_dane  object
#  4   municipio_del_hecho_dane     object
#  5   lesion_no_fatal_de_causa     object
# dtypes: int64(1), object(5)
# memory usage: 86.6+ MB

# %%
# Años que incluye el dataset
non_fatal_injuries_ML_['a_o_del_hecho'].unique()
# Out:
# array([2023, 2024, 2021, 2020, 2022, 2016, 2017, 2018, 2019])

# %% [markdown]
# ### Verificar valores nulos

# %%
non_fatal_injuries_ML_.isnull().sum()
# Out:
# a_o_del_hecho                  0
# sexo_de_la_victima             0
# grupo_de_edad_de_la_victima    0
# departamento_del_hecho_dane    0
# municipio_del_hecho_dane       0
# lesion_no_fatal_de_causa       0
# dtype: int64

# %% [markdown]
# ### Estandarización de categorizaciones
#
# La estandarización de categorizaciones es el proceso de uniformizar y normalizar los valores de las categorías en un conjunto de datos para asegurar la consistencia y evitar discrepancias. Esto es crucial para la calidad y precisión de los análisis

# %%
# Imprimir categorías únicas para columnas de tipo object
categorical_col = ['sexo_de_la_victima', 'grupo_de_edad_de_la_victima' ,'departamento_del_hecho_dane', 'municipio_del_hecho_dane', 'lesion_no_fatal_de_causa']
for column in categorical_col:
    print(f"Categorías en la columna '{column}':")
    print(non_fatal_injuries_ML_[column].unique())
    print()
# Out:
# Categorías en la columna 'sexo_de_la_victima':
# ['Hombre' 'Mujer']
#
# Categorías en la columna 'grupo_de_edad_de_la_victima':
# ['(25 a 29)' '(05 a 09)' '(20 a 24)' '(55 a 59)' '(35 a 39)' '(45 a 49)'
#  '(30 a 34)' '(18 a 19)' '(40 a 44)' '(10 a 14)' '(70 a 74)' '(50 a 54)'
#  '(65 a 69)' '(60 a 64)' '(80 y más)' '(15 a 17)' '(00 a 04)' '(75 a 79)'
#  'Sin información']
#
# Categorías en la columna 'departamento_del_hecho_dane':
# ['Nariño' 'Antioquia' 'Caldas' 'Cauca' 'Putumayo' 'Bogotá, D.C.' 'Boyacá'
#  'Cundinamarca' 'Tolima' 'Meta' 'Huila' 'Casanare' 'Santander' 'Bolívar'
#  'Córdoba' 'Magdalena' 'Chocó' 'Quindío' 'Vichada' 'Cesar'
#  'Valle del Cauca' 'Caquetá' 'Arauca' 'Atlántico' 'Risaralda'
#  'Norte de Santander'
#  'Archipiélago de San Andrés, Providencia y Santa Catalina'
#  'Sin información' 'La Guajira' 'Guaviare' 'Amazonas' 'Sucre' 'Guainía'
#  'Vaupés']
#
# Categorías en la columna 'municipio_del_hecho_dane':
# ...

# %% [markdown]
# - Borrar espacios en blanco al principio y al final, cambiar a mayúsculas, remover acentos y eliminar signos extraños

# %%
import unicodedata

def remove_accents_and_special_chars(input_str):
    # Normalizar la cadena a NFKD
    nfkd_form = unicodedata.normalize('NFKD', input_str)

    # Eliminar acentos
    no_accents = ''.join([c for c in nfkd_form if not unicodedata.combining(c)])

    # Definir caracteres no deseados
    unwanted_chars = [',', ';', '!', '?', '#', '$', '%']

    # Eliminar caracteres no deseados
    cleaned_str = ''.join([c for c in no_accents if c not in unwanted_chars])

    # Remover espacios en blanco al principio y al final, y convertir a mayúsculas
    result = cleaned_str.strip().upper()

    return result

# %%
# Aplicar la función a todas las columnas categóricas
non_fatal_injuries_ML.loc[:,categorical_col] = non_fatal_injuries_ML_[categorical_col].astype(str)
for col in categorical_col:
    non_fatal_injuries_ML_.loc[:,col] = non_fatal_injuries_ML_[col].apply(remove_accents_and_special_chars)

# %% [markdown]
#   - Discretización de la variable grupo_de_edad_de_la_victima

# %%
# Funcion para categorizar
def categorize_age(range):
    if range in ['(00 A 04)', '(05 A 09)', '(10 A 14)']:
        return 'NIÑOS'
    elif range in ['(15 A 17)', '(18 A 19)', '(20 A 24)']:
        return 'JOVENES'
    elif range in ['(25 A 29)', '(30 A 34)', '(35 A 39)', '(40 A 44)', '(45 A 49)', '(50 A 54)', '(55 A 59)']:
        return 'ADULTOS'
    elif range in ['(60 A 64)', '(65 A 69)', '(70 A 74)', '(75 A 79)', '(80 Y MAS)']:
        return 'ADULTOS_MAYORES'
    else:
        return 'SIN INFORMACION'

# %%
# Aplicar funcion a columna
non_fatal_injuries_ML_.loc[:, 'victim_age'] = non_fatal_injuries_ML_['grupo_de_edad_de_la_victima'].apply(categorize_age)
non_fatal_injuries_ML_['victim_age'].unique()
# Out:
# <ipython-input-108-a6a838060944>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   non_fatal_injuries_ML_.loc[:, 'victim_age'] = non_fatal_injuries_ML_['grupo_de_edad_de_la_victima'].apply(categorize_age)
# array(['ADULTOS', 'NIÑOS', 'JOVENES', 'ADULTOS_MAYORES',
#        'SIN INFORMACION'], dtype=object)

# %% [markdown]
# - Normalizar y limpiar las categorias de la columna lesion_fatal_de_causa_externa

# %%
def clean_category(category):
    category = category.replace('LESIONES POR EVENTOS DE TRANSPORTE', 'LESIONES EN ACCIDENTES DE TRANSPORTE')
    category = category.replace('LESIONES EN EVENTOS DE TRANSPORTE', 'LESIONES EN ACCIDENTES DE TRANSPORTE')
    category = category.replace('VIOLENCIA CONTRA NINOS NINAS Y ADOLESCENTES (VIOLENCIA INTRAFAMILIAR)', 'VIOLENCIA INTRAFAMILIAR CONTRA NINOS NINAS Y ADOLESCENTES')
    category = category.replace('VIOLENCIA CONTRA EL ADULTO MAYOR (VIOLENCIA INTRAFAMILIAR)', 'VIOLENCIA INTRAFAMILIAR CONTRA EL ADULTO MAYOR')
    category = category.replace('VIOLENCIA ENTRE OTROS FAMILIARES (VIOLENCIA INTRAFAMILIAR)', 'VIOLENCIA INTRAFAMILIAR ENTRE OTROS FAMILIARES')
    return category

# Aplicar la función a la columna
non_fatal_injuries_ML_.loc[:,'lesion_no_fatal_de_causa'] = non_fatal_injuries_ML_['lesion_no_fatal_de_causa'].apply(clean_category)

# %% [markdown]
# ## Agregar código del municipio a dataframe non_fatal_injuries_ML_ para facilitar la georeferenciación
#
# ### -  Cargar los datos con códigos de departamentos y municipios
#
# Los códigos reales de los municipios de Colombia, están almacenados en la base de datos PostgreSQL del proyecto, en la tabla municipalities dentro del campo dept_mpio_code, junto con la informacion necesaria para georeferenciar todos los municipios y departamentos de Colombia. Este campo guarda el código del municipio en un formato string de exactamente 5 caracteres.
#
# Para hacer esta verificación, previamente exportamos desde la base de datos PostgreSQL un DataFrame con los siguientes campos: dept_name, mpio_name y dept_mpio_code, los cuales contienen la información de los departamentos y municipios oficiales, junto con sus respectivos códigos. Este DataFrame se carga en la siguiente celda y se utiliza para comparar con la columna "codigo_mpio"

# %%
dept_mpios_codes = pd.read_csv("/content/drive/MyDrive/analytics_data_proyect/deptos_mupios.csv", index_col=0, dtype={'dept_mpio_code': str})
print(dept_mpios_codes.info())
dept_mpios_codes.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1121 entries, 0 to 1120
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   dept_mpio_code  1121 non-null   object
#  1   dept_name       1121 non-null   object
#  2   mupio_name      1121 non-null   object
# dtypes: object(3)
# memory usage: 35.0+ KB
# None
#   dept_mpio_code dept_name mupio_name
# 0          97001    VAUPES       MITU
# 1          97161    VAUPES     CARURU
# 2          97511    VAUPES      PACOA
# 3          97666    VAUPES    TARAIRA
# 4          97777    VAUPES  PAPUNAHUA

# %% [markdown]
# ### -  Asegurarse de que los nombres de los departamentos estén escritos de manera identica en cada dataframe
#
#   - Borrar espacios en blanco al principio y al final, cambiar a mayúsculas, remover acentos y eliminar signos extraños

# %%
# Aplicar funcion a columnas 'dept_name', 'mupio_name'
for col in dept_mpios_codes[['dept_name', 'mupio_name']]:
    dept_mpios_codes[col] = dept_mpios_codes[col].apply(remove_accents_and_special_chars)

# %% [markdown]
# - Comparar que los nombres de los departamentos en cada dataframe esten escritos correctamente

# %%
# Función para comparar listas y mostrar diferencias
def compare_lists(df1_col, df2_col, label1, label2):
    # Extraer listas únicas y normalizar
    list1 = set(df1_col.str.strip().str.upper().unique())
    list2 = set(df2_col.str.strip().str.upper().unique())

    # Encontrar diferencias
    only_in_list1 = list1 - list2
    only_in_list2 = list2 - list1

    # Imprimir resultados
    print(f"{label1} que no están en {label2}:")
    print(only_in_list1)
    # print(f"{label2} que no están en {label1}:")
    # print(only_in_list2)
    # print()

# %% [markdown]
#   - Comparar nombres de departamentos en los dataframes

# %%
# Comparar listas de departamento
compare_lists(non_fatal_injuries_ML_['departamento_del_hecho_dane'], dept_mpios_codes['dept_name'],
              "Departamentos en non_fatal_injuries_ML_", "Departamentos dept_mpios_codes")
# Out:
# Departamentos en non_fatal_injuries_ML_ que no están en Departamentos dept_mpios_codes:
# {'SIN INFORMACION'}

# %%
# Verifcar registros sin información de departamentos
sin_inf = non_fatal_injuries_ML_[non_fatal_injuries_ML_['departamento_del_hecho_dane']== 'SIN INFORMACION']
print('Total registros:', len(sin_inf))
sin_inf.head()
# Out:
# Total registros: 436
#        a_o_del_hecho sexo_de_la_victima grupo_de_edad_de_la_victima  \
# 6503            2023             HOMBRE                   (25 A 29)
# 8316            2023              MUJER                   (00 A 04)
# 10839           2023             HOMBRE                   (25 A 29)
# 10880           2023              MUJER                   (40 A 44)
# 36894           2023              MUJER                   (35 A 39)
#
#       departamento_del_hecho_dane municipio_del_hecho_dane  \
# 6503              SIN INFORMACION          SIN INFORMACION
# 8316              SIN INFORMACION          SIN INFORMACION
# 10839             SIN INFORMACION          SIN INFORMACION
# 10880             SIN INFORMACION          SIN INFORMACION
# 36894             SIN INFORMACION          SIN INFORMACION
#
#                                 lesion_no_fatal_de_causa victim_age
# 6503   EXAMENES MEDICO LEGALES POR PESUNTO DELITO SEXUAL    ADULTOS
# ...

# %% [markdown]
# Nota: Por tratarse de un proyecto que enfatiza en la georreferencia no nos interesan datos de los que no se tenga el departamento, ni el municipio donde se produjo el hecho, por lo tanto borramos los registros "SIN INFORMACION" en la columna departamento

# %%
# Conservar únicamente las filas que tienen el departamento identificado
non_fatal_injuries_ML_ = non_fatal_injuries_ML_[non_fatal_injuries_ML_['departamento_del_hecho_dane'] != 'SIN INFORMACION']
len(non_fatal_injuries_ML_[non_fatal_injuries_ML_['departamento_del_hecho_dane'] == 'SIN INFORMACION'])
# Out:
# 0

# %% [markdown]
#  - Confirmar que discrepancia se solucionó

# %%
# Comparar listas de departamento
compare_lists(non_fatal_injuries_ML_['departamento_del_hecho_dane'], dept_mpios_codes['dept_name'],
              "Departamentos en non_fatal_injuries_ML_", "Departamentos dept_mpios_codes")
# Out:
# Departamentos en non_fatal_injuries_ML_ que no están en Departamentos dept_mpios_codes:
# set()

# %% [markdown]
#   b) Aplicar coincidencia difusa para combinacion departamento + municipio en los dos dataframe
#
# Realizar coincidencia difusa (fuzzy matching), significa que puede comparar dos cadenas de texto (strings) y medir su similitud, incluso si no son exactamente iguales. Esta técnica es muy útil en este caso porque si bien los nombres de los departamentos estan debidamente ajustados en los dos df,  los nombres de los municipios pueden tener diferencias (errores de tipeo, variantes en nombres, etc.).
#
# El utilizar la columna del nombre del departamento, es importante en este caso porque en colombia existen municipios con el mismo nombre.
#
#
#  - Instalar la thefuzz en el entorno de google colab, para realizar coincidencia difusa

# %%
# !pip install thefuzz

# %% [markdown]
# - Aplicar thefuzz para coincidencia difusa

# %%
# Crear una clave única de departamento + municipio en ambos datasets
non_fatal_injuries_ML_['dept_mpio'] = non_fatal_injuries_ML_['departamento_del_hecho_dane'] + '_' + non_fatal_injuries_ML_['municipio_del_hecho_dane']
dept_mpios_codes['dept_mpio'] = dept_mpios_codes['dept_name'] + '_' + dept_mpios_codes['mupio_name']

# %%
# Crear un diccionario de municipios y códigos basado en dept_mpios_codes
municipios_dict = dict(zip(dept_mpios_codes['dept_mpio'], dept_mpios_codes['dept_mpio_code']))

# %%
from thefuzz import process

# Funcion para Usar fuzzy matching (thefuzz)
def get_best_match(row, municipios_dict, threshold=80):
    dept_mpio_= row['departamento_del_hecho_dane'] + '_' + row['municipio_del_hecho_dane']

    # Buscar la mejor coincidencia en dept_mpios_codes usando fuzzy matching
    best_match, score = process.extractOne(dept_mpio_, municipios_dict.keys())

    # Si la similitud supera el umbral definido, devolver el código mapeado
    if score >= threshold:
        return municipios_dict[best_match]
    else:
        return 'SIN DATOS'

# %%
# Aplicar la función para encontrar la mejor coincidencia
non_fatal_injuries_ML_['codigo_dane'] = non_fatal_injuries_ML_.apply(
    lambda row: get_best_match(row, municipios_dict, threshold=80), axis=1)

# %% [markdown]
#   - Verificar resultados obtenidos

# %%
non_fatal_injuries_ML_.head()
# Out:
#    a_o_del_hecho sexo_de_la_victima grupo_de_edad_de_la_victima  \
# 0           2023             HOMBRE                   (15 A 17)
# 1           2023             HOMBRE                   (18 A 19)
# 2           2023             HOMBRE                   (20 A 24)
# 3           2023             HOMBRE                   (30 A 34)
# 4           2023             HOMBRE                   (20 A 24)
#
#   departamento_del_hecho_dane municipio_del_hecho_dane  \
# 0                 BOGOTA D.C.              BOGOTA D.C.
# 1                 BOGOTA D.C.              BOGOTA D.C.
# 2                 BOGOTA D.C.              BOGOTA D.C.
# 3                 BOGOTA D.C.              BOGOTA D.C.
# 4                 BOGOTA D.C.              BOGOTA D.C.
#
#   lesion_fatal_de_causa_externa victim_age                dept_mpio  \
# 0                    HOMICIDIOS    JOVENES  BOGOTA D.C._BOGOTA D.C.
# 1                    HOMICIDIOS    JOVENES  BOGOTA D.C._BOGOTA D.C.
# ...

# %% [markdown]
# - Verificar que los códigos de municipios que quedaron en el dataset correspondan solamente a códigos reales

# %%
# Comparar listas de códigos
compare_lists(non_fatal_injuries_ML_['codigo_dane'], dept_mpios_codes['dept_mpio_code'],
              "Códigos de municipios en non_fatal_injuries_ML_", "Códigos de municipios dept_mpios_codes")
# Out:
# Códigos de municipios en non_fatal_injuries_ML_ que no están en Códigos de municipios dept_mpios_codes:
# set()

# %% [markdown]
# ### Procesamiento final como preparación para integrarlo a la bd de datos del proyecto

# %%
# Eliminar columnas innecesarias
columns_to_drop = ['departamento_del_hecho_dane', 'municipio_del_hecho_dane', 'dept_mpio', 'grupo_de_edad_de_la_victima']
final_non_fatal_injuries_ML = non_fatal_injuries_ML_.drop(columns=columns_to_drop)

# %%
# Adicionar columna para trazabilidad de la fuente
final_non_fatal_injuries_ML['source_id_1'] = 44
final_non_fatal_injuries_ML['source_id_2'] = 45
final_non_fatal_injuries_ML['source_id_3'] = 46
final_non_fatal_injuries_ML['source_id_4'] = 47
final_non_fatal_injuries_ML['source_id_5'] = 48
final_non_fatal_injuries_ML['source_id_6'] = 49
final_non_fatal_injuries_ML['source_id_7'] = 50
final_non_fatal_injuries_ML['source_id_8'] = 51

# %%
final_non_fatal_injuries_ML.columns
# Out:
# Index(['a_o_del_hecho', 'sexo_de_la_victima', 'lesion_no_fatal_de_causa',
#        'victim_age', 'codigo_dane', 'source_id_1', 'source_id_2',
#        'source_id_3', 'source_id_4', 'source_id_5', 'source_id_6',
#        'source_id_7', 'source_id_8'],
#       dtype='object')

# %%
# Ajustar nombre de columnas

# Definir el diccionario de traducción
translation_map = {
    'codigo_dane': 'dane_code',
    'a_o_del_hecho': 'year_of_incident',
    'sexo_de_la_victima': 'sex',
    'victim_age': 'age_group',
    'lesion_no_fatal_de_causa': 'cause_of_injury',
    'source_id_1': 'source_1',
    'source_id_2': 'source_2',
    'source_id_3': 'source_3',
    'source_id_4': 'source_4',
    'source_id_5': 'source_5',
    'source_id_6': 'source_6',
    'source_id_7': 'source_7',
    'source_id_8': 'source_8'
}

# Renombrar las columnas
final_non_fatal_injuries_ML.rename(columns=translation_map, inplace=True)

# %%
final_non_fatal_injuries_ML.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1891147 entries, 0 to 1891582
# Data columns (total 13 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   year_of_incident  int64
#  1   sex               object
#  2   cause_of_injury   object
#  3   age_group         object
#  4   dane_code         object
#  5   source_1          int64
#  6   source_2          int64
#  7   source_3          int64
#  8   source_4          int64
#  9   source_5          int64
#  10  source_6          int64
#  11  source_7          int64
#  12  source_8          int64
# dtypes: int64(9), object(4)
# memory usage: 202.0+ MB

# %% [markdown]
# ## Salvar en archivo csv en el drive

# %%
# Guardar en archivos CSV en el drive
final_non_fatal_injuries_ML.to_csv('/content/drive/MyDrive/analytics_data_proyect/initial_transformation/non_fatal_injuries_ML.csv', index=False)
